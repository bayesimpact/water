# %% [markdown]
# # Produce `water_data.json` for the app's use
#
# Authors: everett@bayes.org, mehdi@bayes.org

# %%
from collections import defaultdict
import datetime as datetime
import json
import random

import numpy as np
import pandas as pd

# %matplotlib inline

DATA_DIR = "../data/"

# %% [markdown]
# ### Load a reduced version of the water conservation dataset
#
# #### This was manually edited by me (Everett) from the full dataset (also in the same folder), though in an ideal world I'd do it via a Makefile and code.

# %%
df = pd.read_csv(DATA_DIR + "uw_supplier_data110116_edited.csv", encoding="latin-1")
df = df.rename(columns=dict((c, c.strip()) for c in df.columns))
print("* " + "\n* ".join(df.columns))
# Out:
# * Supplier Name
# * Mandatory Restrictions
# * Reporting Month
# * Total Population Served
# * Conservation Standard (starting in June 2015) *Adjusted in March 2016 **Revised in June 2016
# * REPORTED Total Monthly Potable Water Production Reporting Month
# * REPORTED Monthly CII
# * REPORTED Monthly Ag Use Reporting Month
# * CALCULATED Total Monthly Potable Water Production Reporting Month Gallons
# * CALCULATED Total Monthly Potable Water Production 2013 Gallons
# * CALCULATED Monthly CII Reporting Month
# * CALCULATED R-GPCD Reporting Month
# * % Residential Use
# * Hydrologic Region

# %%
def numberize(i):
    """Convert a string like '100,000' into a float, like 100000.0
    
    Since this data has a lot of variants for zero (missing data,
    null, strings like 'n/a'), we regard any failed float conversion
    as an indicator that the value is 0. This seems to be correct
    based on examining the data.
    """
    try:
        return float(str(i).replace(',', ''))
    except:
        return 0.0

# %%
# Rename wordy columns to more palatable strings
col_rename_dict = {
    'Supplier Name': 'supplier_name',
#     'REPORTED Total Monthly Potable Water Production Reporting Month': 'reported_total_gal',
#     'REPORTED Monthly CII': 'reported_cii_gal',
#     'REPORTED Monthly Ag Use Reporting Month': 'reported_ag_gal',
    "CALCULATED Total Monthly Potable Water Production Reporting Month Gallons": "total_potable_gal",
    "CALCULATED Monthly CII Reporting Month": "cii_gal",
#     "CALCULATED R-GPCD Reporting Month": "r_gpcd",
    'Reporting Month': 'reporting_month',
    'Total Population Served': 'total_population_served',
    'REPORTED Residential Gallons-per-Capita-Day (R-GPCD) (starting in September 2014)': 'r_gpc',
    '% Residential Use': 'percent_residential_use',
    'Hydrologic Region': 'hydrologic_region',
    'Conservation Standard (starting in June 2015) *Adjusted in March 2016 **Revised in June 2016': 'conservation_standard'
}
cols = list(df.columns)
for c in cols:
    if c not in col_rename_dict:
        del df[c]
df = df.rename(columns=col_rename_dict)

# %%
# Compute a bunch of useful columns. Water usage breakdowns, etc.

df['reporting_month'] = pd.to_datetime(df['reporting_month'])
df['month'] = df['reporting_month'].apply(lambda x: x.month)
df['year'] = df['reporting_month'].apply(lambda x: x.year)
df['water_year'] = df['year'] + (df['month'] > 9).astype(int)

# Weirdly, the "total potable water REPORTED" number includes agricultural
# water, whereas the "total potable gallons CALCULATED" does not. The former
# is also reported in a range of units, while the latter converts to gallons.

df['residential_gal'] = df['total_potable_gal'] * (df['percent_residential_use'] / 100.0)
df['cii_gal'] = df['cii_gal'].apply(numberize)
df['other_gal'] = df['total_potable_gal'] * (1 - df['percent_residential_use'] / 100.0) - df['cii_gal']

df['conservation_standard'] = df['conservation_standard'].apply(
    lambda s: 0.0 if pd.isnull(s) else float(s.strip('%')) / 100.0)

df.head()
# Out:
#                            supplier_name reporting_month  \
# 0  East Bay Municipal Utilities District      2016-09-15
# 1  East Bay Municipal Utilities District      2016-08-15
# 2  East Bay Municipal Utilities District      2016-07-15
# 3  East Bay Municipal Utilities District      2016-06-15
# 4  East Bay Municipal Utilities District      2016-05-15
#
#    total_population_served  conservation_standard  total_potable_gal  \
# 0                  1400000                   0.00         5636200000
# 1                  1400000                   0.00         6007500000
# 2                  1400000                   0.00         6056600000
# 3                  1400000                   0.00         5675900000
# 4                  1400000                   0.16         4959300000
#
#       cii_gal  percent_residential_use  hydrologic_region  month  year  \
# 0   912000000                       61  San Francisco Bay      9  2016
# 1  1141000000                       61  San Francisco Bay      8  2016
# 2   994000000                       60  San Francisco Bay      7  2016
# 3   839000000                       61  San Francisco Bay      6  2016
# 4   955000000                       60  San Francisco Bay      5  2016
#
#    water_year  residential_gal   other_gal
# 0        2016       3438082000  1286118000
# 1        2016       3664575000  1201925000
# 2        2016       3633960000  1428640000
# 3        2016       3462299000  1374601000
# 4        2016       2975580000  1028720000

# %%
def computeUsage(df):
    '''Given a dataframe of rows for a single provider, create usage dict.'''
    usage = defaultdict(dict)
    for i, row in df.iterrows():
        m = row['reporting_month'].strftime('%Y-%m')
        pop = float(row['total_population_served'])
        usage['totalPerCapita'][m] = numberize(row['total_potable_gal']) / pop
        usage['residentialPerCapita'][m] = numberize(row['residential_gal']) / pop
        usage['commercialIndustrialPerCapita'][m] = numberize(row['cii_gal']) / pop
        usage['otherPotablePerCapita'][m] = numberize(row['other_gal']) / pop
    
    # For demonstration purposes, add fake data for Oct 2016.
    # Will swap with real data once it's available.
    reference_month = '2015-10'
    if '2015-10' not in usage['totalPerCapita']:
        reference_month = random.choice(list(usage['totalPerCapita'].keys()))
    factor = 1 + random.uniform(-0.1, 0.1)
    for k, v in usage.items():
        usage[k]['2016-10'] = usage[k][reference_month] * factor

    return dict(usage)  # Convert from defaultdict to regular dict

def computePredictions(usage):
    '''Compute monthly usage predictions for the upcoming 12 months.'''
    predictions = {}
    for month in range(1, 13):
        matching_keys = [k for k in usage if k.endswith("%02d" % month)]
        if len(matching_keys) == 0:
            # We have never seen data for this month, can't predict anything
            result = None
        elif len(matching_keys) == 1:
            # Only one occurance of this month, just predict homeostasis
            result = usage[matching_keys[0]]
        else:
            # Assume the year-over-year growth for this month is static.
            matching_keys.sort()
            growth = usage[matching_keys[-1]] / usage[matching_keys[-2]]
            result = usage[matching_keys[-1]] * growth
        predictions['%02d' %  month] = result
    return predictions

# %%
# One dataset identifies water suppliers by ID, the other merely by name. We need to pair them.

providers = pd.read_csv(DATA_DIR + 'provider_ids.tsv', sep='\t')
provider_id_lookup = {}
for p, i in zip(providers['Provider'], providers['ID']):
    provider_id_lookup[p.lower()] = i

# %%
js = {}
for i, items in enumerate(df.groupby("supplier_name").groups.items()):
    name, indices = items
    print(i, name)
    name = name.lower()
    if name not in provider_id_lookup:
        print("Can't find supplier ID for '%s', skipping..." % name)
        continue

    supplier_df = df.loc[indices].set_index('reporting_month', drop=False)
    usage = computeUsage(supplier_df)
    total = usage['totalPerCapita']
    del usage['totalPerCapita']
    preds = computePredictions(total)

    if len(supplier_df[supplier_df['water_year'] == 2016]) < 12:
        print("Don't have complete data for water year 2016 for '%s', skipping..." % name)
        continue
    reduction = supplier_df.loc[datetime.datetime(2016, 9, 15), 'conservation_standard']
    supplier_2016 = supplier_df[supplier_df['water_year'] == 2016]
    used_2016 = (supplier_2016['total_potable_gal'] / supplier_2016['total_population_served']).sum()
    target = (1 - reduction) * used_2016
    js[provider_id_lookup[name]] = {
        "agencyName": name,
        "totalUsage": total,
        "usageByCategory": usage,
        "monthlyPrediction": preds,
        "annualTarget": target,
    }
# Out:
# 0 Suisun-Solano Water Authority
# 1 Crestline Village Water District
# 2 Beaumont-Cherry Valley Water District
# 3 Paradise Irrigation District
# 4 Kingsburg, City of
# 5 Fountain Valley  City of
# 6 Redlands  City of
# 7 Pleasanton  City of
# 8 Galt  City of
# 9 Delano  City of
# 10 California Water Service Company Oroville
# 11 Calexico  City of
# Don't have complete data for water year 2016 for 'calexico  city of', skipping...
# 12 Redding  City of
# 13 Santa Maria  City of
# 14 Monrovia  City of
# Don't have complete data for water year 2016 for 'monrovia  city of', skipping...
# 15 Ukiah  City of
# Don't have complete data for water year 2016 for 'ukiah  city of', skipping...
# 16 Hesperia Water District City of
# 17 Red Bluff  City of
# 18 La Habra  City of Public Works
# 19 Sacramento Suburban Water District
# 20 Citrus Heights Water District
# 21 Castaic Lake Water Agency Santa Clarita Water Division
# 22 San Juan Capistrano  City of
# 23 Monte Vista Water District
# 24 Livermore  City of Division of Water Resources
# 25 Mission Springs Water District
# Don't have complete data for water year 2016 for 'mission springs water district', skipping...
# 26 Lompoc  City of
# 27 Groveland Community Services District
# 28 Eureka  City of
# 29 Santa Cruz  City of
# 30 Antioch  City of
# 31 Reedley  City of
# 32 Golden State Water Company Orcutt
# 33 Sanger  City of
# 34 South Tahoe Public Utilities District
# 35 Golden State Water Company Claremont
# 36 Los Angeles County Public Works Waterworks District 40
# 37 Ventura County Waterworks District No. 8
# 38 Santa Clara  City of
# 39 Patterson  City of
# 40 Mountain House Community Services District
# Can't find supplier ID for 'mountain house community services district', skipping...
# 41 Ontario  City of
# 42 Lakewood  City of
# 43 Soquel Creek Water District
# 44 West Valley Water District
# 45 Redwood City  City of
# 46 Golden State Water Company Artesia
# 47 Oakdale  City of
# 48 Brawley  City of
# 49 Sunnyslope County Water District
# 50 Phelan Pinon Hills Community Services District
# 51 Rio Linda - Elverta Community Water District
# 52 Joshua Basin Water District
# 53 Calaveras County Water District
# 54 Tehachapi, City of
# 55 El Toro Water District
# 56 California Water Service Company Visalia
# 57 Healdsburg  City of
# 58 San Jacinto  City of
# 59 California Water Service Company Redwood Valley
# 60 Truckee-Donner Public Utilities District
# 61 Bella Vista Water District
# 62 Arcata  City of
# 63 Jurupa Community Service District
# 64 Triunfo Sanitation District / Oak Park Water Service
# 65 Loma Linda  City of *
# Can't find supplier ID for 'loma linda  city of *', skipping...
# 66 Benicia  City of
# 67 California Water Service Company Bakersfield
# 68 Shasta Lake  City of
# 69 Rincon Del Diablo Municipal Water District
# 70 Estero Municipal Improvement District
# 71 San Francisco Public Utilities Commission
# 72 Sierra Madre  City of
# 73 Sacramento  City of
# 74 Martinez  City of
# 75 California Water Service Company Westlake
# 76 San Jose  City of
# 77 Lodi  City of Public Works Department
# 78 California-American Water Company Monterey District
# 79 North Tahoe Public Utility District
# 80 Kerman, City of
# 81 Rubio Canyon Land and Water Association
# 82 Newport Beach  City of
# 83 Pismo Beach  City of
# 84 Soledad, City of
# 85 Petaluma  City of
# 86 North Coast County Water District
# 87 Ripon  City of
# 88 Elk Grove Water Service
# 89 Victorville Water District
# 90 Lake Hemet Municipal Water District
# 91 Valley of the Moon Water District
# 92 Santa Fe Springs  City of
# 93 Scotts Valley Water District
# 94 Hi-Desert Water District
# Don't have complete data for water year 2016 for 'hi-desert water district', skipping...
# 95 Mountain View  City of
# 96 Mid-Peninsula Water District
# 97 Fillmore  City of
# 98 Torrance  City of
# Don't have complete data for water year 2016 for 'torrance  city of', skipping...
# 99 Golden State Water Company San Dimas
# 100 Woodland  City of
# 101 Helix Water District
# 102 California Water Service Company Kern River Valley
# 103 El Segundo  City of
# 104 Oxnard  City of
# 105 Morro Bay  City of
# 106 El Dorado Irrigation District
# 107 Dinuba  City of
# Don't have complete data for water year 2016 for 'dinuba  city of', skipping...
# 108 California Water Service Company Chico District
# 109 California Water Service Company Marysville
# 110 San Dieguito Water District
# 111 Banning  City of
# 112 Ceres  City of
# 113 Newhall County Water District
# 114 Menlo Park  City of
# 115 Suburban Water Systems Whittier/La Mirada
# 116 Corcoran, City of
# Can't find supplier ID for 'corcoran, city of', skipping...
# 117 Tahoe City Public Utilities District
# 118 Lincoln  City of
# 119 Goleta Water District
# 120 Marin Municipal Water District
# 121 Ventura County Waterworks District No 1
# 122 Nevada Irrigation District
# 123 Hawthorne  City of
# 124 Casitas Municipal Water District
# 125 Suburban Water Systems San Jose Hills
# 126 Monterey Park  City of
# 127 Humboldt Community Service District
# 128 Santa Rosa  City of
# 129 Chino Hills  City of
# 130 Indian Wells Valley Water District
# 131 Beverly Hills  City of
# 132 Rubidoux Community Service District
# 133 Paramount  City of
# 134 California-American Water Company San Diego District
# 135 Los Banos, City of
# 136 Sacramento County Water Agency
# 137 Golden State Water Company Placentia
# 138 California Water Service Company Los Altos/Suburban
# 139 Santa Fe Irrigation District
# 140 Santa Barbara  City of
# 141 Anderson, City of
# Don't have complete data for water year 2016 for 'anderson, city of', skipping...
# 142 Brentwood  City of
# 143 Lake Arrowhead Community Services District
# 144 American Canyon, City of
# 145 Discovery Bay Community Services District
# 146 Lemoore  City of
# 147 Turlock  City of
# 148 Riverbank  City of
# 149 Fallbrook Public Utility District
# 150 Cambria Community Services District
# 151 Norwalk City of
# 152 Fairfield  City of
# 153 California-American Water Company Los Angeles District
# 154 Lamont Public Utility District
# 155 Hollister  City of
# 156 Golden State Water Company Bell-Bell Gardens
# 157 Atascadero Mutual Water Company
# 158 Downey  City of
# 159 Mammoth Community Water District
# 160 Golden State Water Company Culver City
# 161 Golden State Water Company West Orange
# 162 Valley County Water District
# 163 Lathrop, City of
# Can't find supplier ID for 'lathrop, city of ', skipping...
# 164 Huntington Park  City of
# 165 Pico Water District
# 166 Whittier  City of
# 167 Contra Costa Water District
# 168 Apple Valley Ranchos Water Company
# 169 Walnut Valley Water District
# Don't have complete data for water year 2016 for 'walnut valley water district', skipping...
# 170 Long Beach  City of
# 171 Rosamond Community Service District
# 172 Santa Margarita Water District
# 173 Laguna Beach County Water District
# 174 Olivehurst Public Utility District
# Can't find supplier ID for 'olivehurst public utility district', skipping...
# 175 Santa Ana  City of
# 176 Fruitridge Vista Water Company
# 177 Bakersfield  City of
# 178 San Bernardino County Service Area 64
# 179 Pico Rivera  City of
# 180 Pinedale County Water District
# 181 Wasco  City of
# 182 Yucaipa Valley Water District
# 183 Millbrae  City of
# 184 Sunny Slope Water Company
# 185 California Water Service Company Hermosa/Redondo
# 186 City of Newman Water Department
# Can't find supplier ID for 'city of newman water department', skipping...
# 187 Arvin Community Services District
# 188 San Bruno  City of
# 189 Manhattan Beach  City of
# 190 Quartz Hill Water District
# 191 California Water Service Company King City
# 192 California Water Service Company Mid Peninsula
# 193 Bellflower-Somerset Mutual Water Company
# 194 East Bay Municipal Utilities District
# 195 Exeter  City of
# 196 Perris, City of
# 197 Huntington Beach  City of
# 198 Montecito Water District
# 199 Camarillo  City of
# 200 Lakeside Water District
# 201 Fresno  City of
# 202 Vacaville  City of
# Don't have complete data for water year 2016 for 'vacaville  city of', skipping...
# 203 Golden State Water Company Barstow
# 204 San Clemente  City of
# 205 California Water Service Company Livermore
# 206 San Lorenzo Valley Water District
# 207 Eastern Municipal Water District
# 208 San Gabriel Valley Water Company
# 209 Bakman Water Company
# 210 Orange Vale Water Company
# 211 Olivenhain Municipal Water District
# 212 Humboldt Bay Municipal Water District
# 213 California-American Water Ventura District
# 214 Pomona  City of
# 215 Myoma Dunes Mutual Water Company
# 216 Otay Water District
# 217 Compton  City of
# 218 Modesto, City of
# 219 Blythe  City of
# 220 South Pasadena  City of
# 221 Hillsborough  Town of
# 222 San Jose Water Company
# 223 Crescenta Valley Water District
# 224 Orange  City of
# 225 La Palma  City of
# 226 Porterville  City of
# 227 Hemet  City of
# 228 San Diego  City of
# 229 Rainbow Municipal Water District
# Don't have complete data for water year 2016 for 'rainbow municipal water district', skipping...
# 230 Lincoln Avenue Water Company
# 231 Mesa Water District
# Can't find supplier ID for 'mesa water district', skipping...
# 232 Sonoma  City of
# 233 El Monte  City of
# 234 Elsinore Valley Municipal Water District
# 235 Shafter  City of
# 236 Vaughn Water Company
# 237 Del Oro Water Company
# 238 San Fernando  City of
# 239 Rowland Water District
# 240 Sunnyvale  City of
# 241 McKinleyville Community Service District
# 242 Placer County Water Agency
# 243 Yuba City  City of
# 244 Coachella  City of
# 245 East Orange County Water District
# Don't have complete data for water year 2016 for 'east orange county water district', skipping...
# 246 California-American Water Company Sacramento District
# 247 San Gabriel County Water District
# 248 Valencia Water Company
# 249 California Water Service Company Dominguez
# 250 Pasadena  City of
# 251 Cucamonga Valley Water District
# 252 Camrosa Water District
# 253 Diablo Water District
# 254 Westborough Water District
# 255 Merced  City of
# 256 Greenfield, City of
# 257 Carlsbad Municipal Water District
# 258 Tuolumne Utilities District
# 259 Upland  City of
# 260 Glendale  City of
# 261 Ramona Municipal Water District
# 262 Great Oaks Water Company Incorporated
# 263 Madera  City of
# 264 Hayward  City of
# 265 Milpitas  City of
# 266 Vista Irrigation District
# 267 Lomita  City of
# 268 Yreka, City of
# 269 Pittsburg  City of
# 270 South Gate  City of
# 271 California Water Service Company Salinas District
# 272 Livingston  City of
# 273 City of Big Bear Lake, Dept of Water & Power
# Can't find supplier ID for 'city of big bear lake, dept of water & power', skipping...
# 274 Burbank  City of
# 275 California Water Service Company Antelope Valley
# 276 Riverside Highland Water Company
# 277 Golden State Water Company S Arcadia
# 278 Amador Water Agency
# 279 California Water Service Company Willows
# 280 Vallejo  City of
# 281 Golden State Water Company Southwest
# 282 North Marin Water District
# 283 Desert Water Agency
# 284 Sweetwater Authority
# 285 Padre Dam Municipal Water District
# 286 Fortuna  City of
# 287 San Buenaventura  City of
# 288 Burlingame  City of
# 289 East Valley Water District
# 290 Watsonville  City of
# 291 Tulare, City of
# 292 Norco  City of
# 293 Chino  City of
# 294 Gilroy  City of
# 295 Lee Lake Water District
# 296 Tustin  City of
# 297 Daly City  City of
# 298 Paso Robles  City of
# 299 Valley Water Company
# 300 Davis  City of
# 301 Western Municipal Water District of Riverside
# 302 Moulton Niguel Water District
# 303 La Verne  City of
# 304 Oceanside  City of
# 305 San Luis Obispo  City of
# 306 Carpinteria Valley Water District
# 307 San Gabriel Valley Fontana Water Company
# 308 Georgetown Divide Public Utilities District
# 309 Nipomo Community Services District
# 310 Santa Paula  City of
# 311 Clovis  City of
# 312 Vallecitos Water District
# 313 Coalinga City of
# Can't find supplier ID for 'coalinga city of', skipping...
# 314 Morgan Hill  City of
# 315 Stockton  City of
# 316 Carmichael Water District
# 317 Westminster  City of
# 318 Brea  City of
# 319 Folsom  City of
# 320 Rohnert Park  City of
# 321 Alco Water Service
# 322 Golden State Water Company Bay Point
# 323 Atwater  City of
# 324 Oildale Mutual Water Company
# 325 Los Angeles Department of Water and Power
# 326 Roseville  City of
# Don't have complete data for water year 2016 for 'roseville  city of', skipping...
# 327 Napa  City of
# 328 Golden State Water Company Florence Graham
# 329 Thousand Oaks  City of
# 330 Valley Center Municipal Water District
# 331 Irvine Ranch Water District
# 332 Colton, City of
# 333 Rancho California Water District
# 334 East Palo Alto, City of
# 335 El Centro  City of
# 336 Arroyo Grande  City of
# 337 California Water Service Company Dixon, City of
# 338 Coachella Valley Water District
# 339 Marina Coast Water District
# 340 Twentynine Palms Water District
# 341 Garden Grove  City of
# 342 California Water Service Company Selma
# 343 San Juan Water District
# 344 Lynwood  City of
# Don't have complete data for water year 2016 for 'lynwood  city of', skipping...
# 345 Azusa  City of
# 346 Montebello Land and Water Company
# 347 Golden State Water Company Simi Valley
# 348 Windsor, Town of
# 349 San Bernardino County Service Area 70J
# Can't find supplier ID for 'san bernardino county service area 70j', skipping...
# 350 Susanville  City of
# Don't have complete data for water year 2016 for 'susanville  city of', skipping...
# 351 Poway  City of
# 352 Buena Park  City of
# 353 Golden State Water Company Cordova
# 354 California Water Service Company East Los Angeles
# 355 Corona  City of
# 356 Port Hueneme  City of
# 357 Park Water Company
# 358 Tracy  City of
# 359 Cloverdale
# Don't have complete data for water year 2016 for 'cloverdale', skipping...
# 360 Hanford  City of
# 361 Imperial, City of
# 362 Inglewood  City of
# 363 Los Angeles County Public Works Waterworks District 29
# 364 Indio  City of
# 365 Alameda County Water District
# 366 South Coast Water District
# 367 California Water Service Company South San Francisco
# 368 Linda County Water District
# 369 Alhambra  City of
# 370 Trabuco Canyon Water District
# 371 San Bernardino  City of
# 372 Orchard Dale Water District
# 373 Las Virgenes Municipal Water District
# 374 Cerritos  City of
# 375 West Kern Water District
# 376 Yorba Linda Water District
# 377 California Water Service Company Palos Verdes
# 378 Santa Monica  City of
# 379 Palo Alto  City of
# 380 Crescent City  City of
# 381 Grover Beach  City of
# Don't have complete data for water year 2016 for 'grover beach  city of', skipping...
# 382 Seal Beach  City of
# 383 Palmdale Water District
# 384 Adelanto City of
# 385 East Niles Community Service District
# 386 West Sacramento  City of
# 387 Manteca  City of
# 388 Coastside County Water District
# 389 Big Bear City Community Services District
# Can't find supplier ID for 'big bear city community services district', skipping...
# 390 Fair Oaks Water District
# 391 Riverside  City of
# 392 Rialto  City of
# 393 Glendora  City of
# 394 Escondido  City of
# 395 Golden State Water Company Norwalk
# 396 Arcadia  City of
# Don't have complete data for water year 2016 for 'arcadia  city of', skipping...
# 397 Fullerton  City of
# 398 Dublin San Ramon Services District
# 399 California Water Service Company Bear Gulch
# 400 Rio Vista, city of
# 401 South Feather Water and Power Agency
# Don't have complete data for water year 2016 for 'south feather water and power agency', skipping...
# 402 Covina  City of
# Can't find supplier ID for 'covina  city of ', skipping...
# 403 Anaheim  City of
# 404 Golden State Water Company S San Gabriel
# 405 California City  City of
# 406 Sweetwater Springs Water District
# 407 California Water Service Company Stockton

# %%
js[provider_id_lookup['East Bay Municipal Utilities District'.lower()]]
# Out:
# {'agencyName': 'east bay municipal utilities district',
#  'annualTarget': 39940.788195133602,
#  'monthlyPrediction': {'01': 2417.0425868076827,
#   '02': 2307.3946062486384,
#   '03': 2162.496771084676,
#   '04': 2569.9142125418007,
#   '05': 3744.794391501367,
#   '06': 4781.496866924954,
#   '07': 5052.842907325889,
#   '08': 4874.674539013777,
#   '09': 4451.649133761039,
#   '10': 3126.39045587951,
#   '11': 2555.6796736092665,
#   '12': 2564.2099279337895},
#  'totalUsage': {'2014-06': 4786.015037593985,
#   '2014-07': 4954.962406015037,
#   '2014-08': 4511.965192168238,
#   '2014-09': 4121.02973168963,
#   '2014-10': 3894.5612762871647,
#   '2014-11': 3042.3495286439447,
#   '2014-12': 2783.901377810007,
#   '2015-01': 2946.906474820144,
#   '2015-02': 2709.2805755395684,
#   '2015-03': 3345.4676258992804,
#   '2015-04': 3206.4028776978416,
#   '2015-05': 3350.863309352518,
#   '2015-06': 3437.5539568345325,
#   '2015-07': 3703.956834532374,
#   '2015-08': 3777.338129496403,
#   '2015-09': 3640.7913669064747,
#   '2015-10': 3511.5107913669067,
#   '2015-11': 2788.4172661870502,
#   '2015-12': 2671.798561151079,
#   '2016-01': 2668.8571428571427,
#   '2016-02': 2500.275862142857,
#   '2016-03': 2689.714285714286,
#   '2016-04': 2870.5714285714284,
#   '2016-05': 3542.3571428571427,
#   '2016-06': 4054.214285714286,
#   '2016-07': 4326.142857142857,
#   '2016-08': 4291.071428571428,
#   '2016-09': 4025.8571428571427,
#   '2016-10': 3313.359899535123},
#  'usageByCategory': {'commercialIndustrialPerCapita': {'2014-06': 0.0,
#    '2014-07': 0.0,
#    '2014-08': 0.0,
#    '2014-09': 0.0,
#    '2014-10': 0.0,
#    '2014-11': 0.0,
#    '2014-12': 0.0,
#    '2015-01': 0.0,
#    '2015-02': 0.0,
#    '2015-03': 0.0,
#    '2015-04': 0.0,
#    '2015-05': 0.0,
#    '2015-06': 653.8129496402878,
#    '2015-07': 687.0503597122303,
#    '2015-08': 717.410071942446,
#    '2015-09': 720.5035971223022,
#    '2015-10': 715.8273381294964,
#    '2015-11': 609.3525179856115,
#    '2015-12': 606.4748201438849,
#    '2016-01': 857.8571428571429,
#    '2016-02': 564.1379310714286,
#    '2016-03': 578.5714285714286,
#    '2016-04': 592.8571428571429,
#    '2016-05': 682.1428571428571,
#    '2016-06': 599.2857142857143,
#    '2016-07': 710.0,
#    '2016-08': 815.0,
#    '2016-09': 651.4285714285714,
#    '2016-10': 675.4339479691554},
#   'otherPotablePerCapita': {'2014-06': 1483.6646616541354,
#    '2014-07': 1536.0383458646618,
#    '2014-08': 1759.6664249456128,
#    '2014-09': 1607.2015953589557,
#    '2014-10': 1557.8245105148658,
#    '2014-11': 1186.5163161711384,
#    '2014-12': 1057.8825235678028,
#    '2015-01': 1119.8244604316546,
#    '2015-02': 1056.6194244604317,
#    '2015-03': 1304.7323741007194,
#    '2015-04': 1218.4330935251799,
#    '2015-05': 1340.3453237410072,
#    '2015-06': 686.8330935251798,
#    '2015-07': 794.5323741007194,
#    '2015-08': 755.7517985611511,
#    '2015-09': 699.405035971223,
#    '2015-10': 688.7769784172662,
#    '2015-11': 478.13021582733813,
#    '2015-12': 408.8086330935252,
#    '2016-01': 156.30857142857144,
#    '2016-02': 410.9696551642857,
#    '2016-03': 470.41714285714284,
#    '2016-04': 497.96,
#    '2016-05': 734.8,
#    '2016-06': 981.8578571428571,
#    '2016-07': 1020.4571428571429,
#    '2016-08': 858.5178571428571,
#    '2016-09': 918.6557142857143,
#    '2016-10': 649.9100118448938},
#   'residentialPerCapita': {'2014-06': 3302.3503759398495,
#    '2014-07': 3418.924060150376,
#    '2014-08': 2752.298767222625,
#    '2014-09': 2513.8281363306746,
#    '2014-10': 2336.736765772299,
#    '2014-11': 1855.8332124728063,
#    '2014-12': 1726.0188542422045,
#    '2015-01': 1827.0820143884891,
#    '2015-02': 1652.6611510791367,
#    '2015-03': 2040.7352517985612,
#    '2015-04': 1987.9697841726618,
#    '2015-05': 2010.5179856115108,
#    '2015-06': 2096.907913669065,
#    '2015-07': 2222.3741007194244,
#    '2015-08': 2304.1762589928057,
#    '2015-09': 2220.8827338129495,
#    '2015-10': 2106.906474820144,
#    '2015-11': 1700.9345323741006,
#    '2015-12': 1656.515107913669,
#    '2016-01': 1654.6914285714286,
#    '2016-02': 1525.1682759071427,
#    '2016-03': 1640.7257142857143,
#    '2016-04': 1779.7542857142857,
#    '2016-05': 2125.4142857142856,
#    '2016-06': 2473.070714285714,
#    '2016-07': 2595.6857142857143,
#    '2016-08': 2617.5535714285716,
#    '2016-09': 2455.772857142857,
#    '2016-10': 1988.015939721074}}}

# %%
with open(DATA_DIR + 'usage.json', 'w') as f:
    f.write(json.dumps(js, indent=4))
