# %% [markdown]
# # Produce `water_data.json` for the app's use
#
# Authors: everett@bayes.org, mehdi@bayes.org

# %%
from collections import defaultdict
import datetime as datetime
import json
import random

import numpy as np
import pandas as pd

# %matplotlib inline

DATA_DIR = "../data/"

# %% [markdown]
# ### Load a reduced version of the water conservation dataset
#
# #### This was manually edited by me (Everett) from the full dataset (also in the same folder), though in an ideal world I'd do it via a Makefile and code.

# %%
df = pd.read_csv(DATA_DIR + "uw_supplier_data110116_edited.csv", encoding="latin-1")
df = df.rename(columns=dict((c, c.strip()) for c in df.columns))
print("* " + "\n* ".join(df.columns))
# Out:
# * Supplier Name
# * Mandatory Restrictions
# * Reporting Month
# * Total Population Served
# * Conservation Standard (starting in June 2015) *Adjusted in March 2016 **Revised in June 2016
# * REPORTED Total Monthly Potable Water Production Reporting Month
# * REPORTED Monthly CII
# * REPORTED Monthly Ag Use Reporting Month
# * CALCULATED Total Monthly Potable Water Production Reporting Month Gallons
# * CALCULATED Total Monthly Potable Water Production 2013 Gallons
# * CALCULATED Monthly CII Reporting Month
# * CALCULATED R-GPCD Reporting Month
# * % Residential Use
# * Hydrologic Region

# %%
def numberize(i):
    """Convert a string like '100,000' into a float, like 100000.0
    
    Since this data has a lot of variants for zero (missing data,
    null, strings like 'n/a'), we regard any failed float conversion
    as an indicator that the value is 0. This seems to be correct
    based on examining the data.
    """
    try:
        return float(str(i).replace(',', ''))
    except:
        return 0.0

# %%
# Rename wordy columns to more palatable strings
col_rename_dict = {
    'Supplier Name': 'supplier_name',
#     'REPORTED Total Monthly Potable Water Production Reporting Month': 'reported_total_gal',
#     'REPORTED Monthly CII': 'reported_cii_gal',
#     'REPORTED Monthly Ag Use Reporting Month': 'reported_ag_gal',
    "CALCULATED Total Monthly Potable Water Production Reporting Month Gallons": "total_potable_gal",
    "CALCULATED Monthly CII Reporting Month": "cii_gal",
#     "CALCULATED R-GPCD Reporting Month": "r_gpcd",
    'Reporting Month': 'reporting_month',
    'Total Population Served': 'total_population_served',
    'REPORTED Residential Gallons-per-Capita-Day (R-GPCD) (starting in September 2014)': 'r_gpc',
    '% Residential Use': 'percent_residential_use',
    'Hydrologic Region': 'hydrologic_region',
    'Conservation Standard (starting in June 2015) *Adjusted in March 2016 **Revised in June 2016': 'conservation_standard'
}
cols = list(df.columns)
for c in cols:
    if c not in col_rename_dict:
        del df[c]
df = df.rename(columns=col_rename_dict)

# %%
# Compute a bunch of useful columns. Water usage breakdowns, etc.

df['reporting_month'] = pd.to_datetime(df['reporting_month'])
df['month'] = df['reporting_month'].apply(lambda x: x.month)
df['year'] = df['reporting_month'].apply(lambda x: x.year)
df['water_year'] = df['year'] + (df['month'] > 9).astype(int)

# Weirdly, the "total potable water REPORTED" number includes agricultural
# water, whereas the "total potable gallons CALCULATED" does not. The former
# is also reported in a range of units, while the latter converts to gallons.

df['residential_gal'] = df['total_potable_gal'] * (df['percent_residential_use'] / 100.0)
df['cii_gal'] = df['cii_gal'].apply(numberize)
df['other_gal'] = df['total_potable_gal'] * (1 - df['percent_residential_use'] / 100.0) - df['cii_gal']

df['conservation_standard'] = df['conservation_standard'].apply(
    lambda s: 0.0 if pd.isnull(s) else float(s.strip('%')) / 100.0)

df.head()
# Out:
#                            supplier_name reporting_month  \
# 0  East Bay Municipal Utilities District      2016-09-15
# 1  East Bay Municipal Utilities District      2016-08-15
# 2  East Bay Municipal Utilities District      2016-07-15
# 3  East Bay Municipal Utilities District      2016-06-15
# 4  East Bay Municipal Utilities District      2016-05-15
#
#    total_population_served  conservation_standard  total_potable_gal  \
# 0                  1400000                   0.00         5636200000
# 1                  1400000                   0.00         6007500000
# 2                  1400000                   0.00         6056600000
# 3                  1400000                   0.00         5675900000
# 4                  1400000                   0.16         4959300000
#
#       cii_gal  percent_residential_use  hydrologic_region  month  year  \
# 0   912000000                       61  San Francisco Bay      9  2016
# 1  1141000000                       61  San Francisco Bay      8  2016
# 2   994000000                       60  San Francisco Bay      7  2016
# 3   839000000                       61  San Francisco Bay      6  2016
# 4   955000000                       60  San Francisco Bay      5  2016
#
#    water_year  residential_gal   other_gal
# 0        2016       3438082000  1286118000
# 1        2016       3664575000  1201925000
# 2        2016       3633960000  1428640000
# 3        2016       3462299000  1374601000
# 4        2016       2975580000  1028720000

# %%
def computeUsage(df):
    '''Given a dataframe of rows for a single provider, create usage dict.'''
    usage = defaultdict(dict)
    for i, row in df.iterrows():
        m = row['reporting_month'].strftime('%Y-%m')
        pop = float(row['total_population_served'])
        usage['totalPerCapita'][m] = numberize(row['total_potable_gal']) / pop
        usage['residentialPerCapita'][m] = numberize(row['residential_gal']) / pop
        usage['commercialIndustrialPerCapita'][m] = numberize(row['cii_gal']) / pop
        usage['otherPotablePerCapita'][m] = numberize(row['other_gal']) / pop
    
    # For demonstration purposes, add fake data for Oct 2016.
    # Will swap with real data once it's available.
    reference_month = '2015-10'
    if '2015-10' not in usage['totalPerCapita']:
        reference_month = random.choice(list(usage['totalPerCapita'].keys()))
    factor = 1 + random.uniform(-0.1, 0.1)
    for k, v in usage.items():
        usage[k]['2016-10'] = usage[k][reference_month] * factor

    return dict(usage)  # Convert from defaultdict to regular dict

def computePredictions(usage):
    '''Compute monthly usage predictions for the upcoming 12 months.'''
    predictions = {}
    for month in range(1, 13):
        matching_keys = [k for k in usage if k.endswith("%02d" % month)]
        if len(matching_keys) == 0:
            # We have never seen data for this month, can't predict anything
            result = None
        elif len(matching_keys) == 1:
            # Only one occurance of this month, just predict homeostasis
            result = usage[matching_keys[0]]
        else:
            # Assume the year-over-year growth for this month is static.
            matching_keys.sort()
            growth = usage[matching_keys[-1]] / usage[matching_keys[-2]]
            result = usage[matching_keys[-1]] * growth
        predictions['%02d' %  month] = result
    return predictions

# %%
# One dataset identifies water suppliers by ID, the other merely by name. We need to pair them.

providers = pd.read_csv(DATA_DIR + 'provider_ids.tsv', sep='\t')
provider_id_lookup = {}
for p, i in zip(providers['Provider'], providers['ID']):
    provider_id_lookup[p.lower()] = i

# %%
js = {}
for i, items in enumerate(df.groupby("supplier_name").groups.items()):
    name, indices = items
    print(i, name)
    name = name.lower()
    if name not in provider_id_lookup:
        print("Can't find supplier ID for '%s', skipping..." % name)
        continue

    supplier_df = df.loc[indices].set_index('reporting_month', drop=False)
    usage = computeUsage(supplier_df)
    total = usage['totalPerCapita']
    del usage['totalPerCapita']
    preds = computePredictions(total)

    if len(supplier_df[supplier_df['water_year'] == 2016]) < 12:
        print("Don't have complete data for water year 2016 for '%s', skipping..." % name)
        continue
    reduction = supplier_df.loc[datetime.datetime(2016, 9, 15), 'conservation_standard']
    used_2016 = supplier_df['total_potable_gal'][supplier_df['water_year'] == 2016].sum()
    target = (1 - reduction) * used_2016
    js[provider_id_lookup[name]] = {
        "agencyName": name,
        "totalUsage": total,
        "usageByCategory": usage,
        "monthlyPrediction": preds,
        "annualTarget": target,
    }
# Out:
# 0 Vaughn Water Company
# 1 Delano  City of
# 2 Manteca  City of
# 3 Santa Cruz  City of
# 4 Glendale  City of
# 5 Paso Robles  City of
# 6 Yreka, City of
# 7 Escondido  City of
# 8 Bellflower-Somerset Mutual Water Company
# 9 Rohnert Park  City of
# 10 Tehachapi, City of
# 11 South Tahoe Public Utilities District
# 12 Golden State Water Company Florence Graham
# 13 Greenfield, City of
# 14 Oceanside  City of
# 15 Oakdale  City of
# 16 Rowland Water District
# 17 Thousand Oaks  City of
# 18 Suburban Water Systems San Jose Hills
# 19 Twentynine Palms Water District
# 20 Ontario  City of
# 21 Rio Vista, city of
# 22 Norco  City of
# 23 Tahoe City Public Utilities District
# 24 Compton  City of
# 25 Loma Linda  City of *
# Can't find supplier ID for 'loma linda  city of *', skipping...
# 26 Dublin San Ramon Services District
# 27 Davis  City of
# 28 Lincoln  City of
# 29 North Tahoe Public Utility District
# 30 Lompoc  City of
# 31 California-American Water Company Los Angeles District
# 32 California Water Service Company Mid Peninsula
# 33 Antioch  City of
# 34 South Gate  City of
# 35 Sonoma  City of
# 36 Mission Springs Water District
# Don't have complete data for water year 2016 for 'mission springs water district', skipping...
# 37 Bakersfield  City of
# 38 Valley Center Municipal Water District
# 39 East Orange County Water District
# Don't have complete data for water year 2016 for 'east orange county water district', skipping...
# 40 San Diego  City of
# 41 Walnut Valley Water District
# Don't have complete data for water year 2016 for 'walnut valley water district', skipping...
# 42 California Water Service Company Willows
# 43 Olivenhain Municipal Water District
# 44 Vista Irrigation District
# 45 San Bernardino County Service Area 64
# 46 Morro Bay  City of
# 47 Joshua Basin Water District
# 48 Lakeside Water District
# 49 Eastern Municipal Water District
# 50 San Fernando  City of
# 51 Humboldt Bay Municipal Water District
# 52 Lamont Public Utility District
# 53 Orange Vale Water Company
# 54 Madera  City of
# 55 California Water Service Company Bakersfield
# 56 Golden State Water Company Orcutt
# 57 Myoma Dunes Mutual Water Company
# 58 Tustin  City of
# 59 Windsor, Town of
# 60 Petaluma  City of
# 61 Sweetwater Springs Water District
# 62 Coastside County Water District
# 63 Placer County Water Agency
# 64 Westminster  City of
# 65 Sierra Madre  City of
# 66 Carpinteria Valley Water District
# 67 Benicia  City of
# 68 Corcoran, City of
# Can't find supplier ID for 'corcoran, city of', skipping...
# 69 Los Banos, City of
# 70 Calaveras County Water District
# 71 Alameda County Water District
# 72 Cerritos  City of
# 73 California Water Service Company Selma
# 74 Scotts Valley Water District
# 75 Ramona Municipal Water District
# 76 Santa Barbara  City of
# 77 Healdsburg  City of
# 78 Fresno  City of
# 79 Sunnyvale  City of
# 80 Golden State Water Company Bay Point
# 81 Ventura County Waterworks District No 1
# 82 Marin Municipal Water District
# 83 Palo Alto  City of
# 84 Hayward  City of
# 85 Ventura County Waterworks District No. 8
# 86 Lake Arrowhead Community Services District
# 87 Pinedale County Water District
# 88 Redlands  City of
# 89 Lincoln Avenue Water Company
# 90 California Water Service Company Redwood Valley
# 91 Estero Municipal Improvement District
# 92 California Water Service Company Hermosa/Redondo
# 93 McKinleyville Community Service District
# 94 North Marin Water District
# 95 Moulton Niguel Water District
# 96 Merced  City of
# 97 Alco Water Service
# 98 Sweetwater Authority
# 99 Hanford  City of
# 100 Pismo Beach  City of
# 101 East Niles Community Service District
# 102 Bella Vista Water District
# 103 Discovery Bay Community Services District
# 104 Santa Paula  City of
# 105 Valley County Water District
# 106 Newhall County Water District
# 107 Morgan Hill  City of
# 108 Lodi  City of Public Works Department
# 109 Pico Rivera  City of
# 110 Burbank  City of
# 111 Crescenta Valley Water District
# 112 Oildale Mutual Water Company
# 113 California Water Service Company Kern River Valley
# 114 City of Big Bear Lake, Dept of Water & Power
# Can't find supplier ID for 'city of big bear lake, dept of water & power', skipping...
# 115 San Francisco Public Utilities Commission
# 116 San Luis Obispo  City of
# 117 Arroyo Grande  City of
# 118 Poway  City of
# 119 Burlingame  City of
# 120 Long Beach  City of
# 121 Olivehurst Public Utility District
# Can't find supplier ID for 'olivehurst public utility district', skipping...
# 122 Lathrop, City of
# Can't find supplier ID for 'lathrop, city of ', skipping...
# 123 Golden State Water Company Simi Valley
# 124 Jurupa Community Service District
# 125 La Palma  City of
# 126 Pico Water District
# 127 Phelan Pinon Hills Community Services District
# 128 Truckee-Donner Public Utilities District
# 129 Rubidoux Community Service District
# 130 Lee Lake Water District
# 131 Riverside  City of
# 132 Golden State Water Company Artesia
# 133 Indian Wells Valley Water District
# 134 Marina Coast Water District
# 135 Santa Fe Springs  City of
# 136 Whittier  City of
# 137 Orchard Dale Water District
# 138 Golden State Water Company Southwest
# 139 Soquel Creek Water District
# 140 Santa Clara  City of
# 141 California Water Service Company Visalia
# 142 California-American Water Company Sacramento District
# 143 Newport Beach  City of
# 144 California Water Service Company Chico District
# 145 Diablo Water District
# 146 Coachella  City of
# 147 Golden State Water Company Claremont
# 148 Suisun-Solano Water Authority
# 149 Adelanto City of
# 150 Azusa  City of
# 151 American Canyon, City of
# 152 Monrovia  City of
# Don't have complete data for water year 2016 for 'monrovia  city of', skipping...
# 153 Lake Hemet Municipal Water District
# 154 Riverbank  City of
# 155 Golden State Water Company S Arcadia
# 156 Big Bear City Community Services District
# Can't find supplier ID for 'big bear city community services district', skipping...
# 157 Pomona  City of
# 158 Fruitridge Vista Water Company
# 159 East Bay Municipal Utilities District
# 160 North Coast County Water District
# 161 Inglewood  City of
# 162 Millbrae  City of
# 163 Imperial, City of
# 164 Santa Margarita Water District
# 165 Clovis  City of
# 166 Anderson, City of
# Don't have complete data for water year 2016 for 'anderson, city of', skipping...
# 167 Golden State Water Company Cordova
# 168 California Water Service Company King City
# 169 Pleasanton  City of
# 170 Irvine Ranch Water District
# 171 Valley Water Company
# 172 San Juan Water District
# 173 Santa Rosa  City of
# 174 Daly City  City of
# 175 Castaic Lake Water Agency Santa Clarita Water Division
# 176 California Water Service Company Marysville
# 177 California Water Service Company Antelope Valley
# 178 El Dorado Irrigation District
# 179 Folsom  City of
# 180 Mountain House Community Services District
# Can't find supplier ID for 'mountain house community services district', skipping...
# 181 Golden State Water Company West Orange
# 182 California Water Service Company East Los Angeles
# 183 Suburban Water Systems Whittier/La Mirada
# 184 Napa  City of
# 185 Hollister  City of
# 186 Golden State Water Company S San Gabriel
# 187 Ukiah  City of
# Don't have complete data for water year 2016 for 'ukiah  city of', skipping...
# 188 Arvin Community Services District
# 189 Groveland Community Services District
# 190 Brentwood  City of
# 191 Grover Beach  City of
# Don't have complete data for water year 2016 for 'grover beach  city of', skipping...
# 192 California City  City of
# 193 Hillsborough  Town of
# 194 Carmichael Water District
# 195 Yorba Linda Water District
# 196 San Clemente  City of
# 197 Atwater  City of
# 198 San Dieguito Water District
# 199 California-American Water Ventura District
# 200 Fullerton  City of
# 201 Santa Fe Irrigation District
# 202 Golden State Water Company Norwalk
# 203 Livermore  City of Division of Water Resources
# 204 El Monte  City of
# 205 San Gabriel Valley Fontana Water Company
# 206 Cucamonga Valley Water District
# 207 San Bruno  City of
# 208 Milpitas  City of
# 209 West Kern Water District
# 210 Hi-Desert Water District
# Don't have complete data for water year 2016 for 'hi-desert water district', skipping...
# 211 Mid-Peninsula Water District
# 212 Hemet  City of
# 213 Rubio Canyon Land and Water Association
# 214 Amador Water Agency
# 215 Bakman Water Company
# 216 Victorville Water District
# 217 Monte Vista Water District
# 218 Downey  City of
# 219 Paramount  City of
# 220 Galt  City of
# 221 Seal Beach  City of
# 222 Port Hueneme  City of
# 223 Arcata  City of
# 224 California Water Service Company Livermore
# 225 Los Angeles Department of Water and Power
# 226 Shafter  City of
# 227 Western Municipal Water District of Riverside
# 228 Corona  City of
# 229 Tracy  City of
# 230 Atascadero Mutual Water Company
# 231 Montecito Water District
# 232 Beaumont-Cherry Valley Water District
# 233 San Buenaventura  City of
# 234 West Valley Water District
# 235 California Water Service Company Salinas District
# 236 Red Bluff  City of
# 237 Sacramento County Water Agency
# 238 South Coast Water District
# 239 Trabuco Canyon Water District
# 240 Vallejo  City of
# 241 California Water Service Company Oroville
# 242 Lemoore  City of
# 243 California Water Service Company South San Francisco
# 244 Pasadena  City of
# 245 California Water Service Company Los Altos/Suburban
# 246 Colton, City of
# 247 California Water Service Company Bear Gulch
# 248 Eureka  City of
# 249 Buena Park  City of
# 250 Cloverdale
# Don't have complete data for water year 2016 for 'cloverdale', skipping...
# 251 California-American Water Company Monterey District
# 252 Tuolumne Utilities District
# 253 Oxnard  City of
# 254 Contra Costa Water District
# 255 West Sacramento  City of
# 256 Carlsbad Municipal Water District
# 257 Fountain Valley  City of
# 258 Mountain View  City of
# 259 Del Oro Water Company
# 260 Turlock  City of
# 261 Ripon  City of
# 262 Arcadia  City of
# Don't have complete data for water year 2016 for 'arcadia  city of', skipping...
# 263 Citrus Heights Water District
# 264 Santa Ana  City of
# 265 Park Water Company
# 266 California Water Service Company Westlake
# 267 California-American Water Company San Diego District
# 268 Martinez  City of
# 269 Westborough Water District
# 270 Patterson  City of
# 271 Beverly Hills  City of
# 272 East Palo Alto, City of
# 273 Elk Grove Water Service
# 274 Kerman, City of
# 275 La Verne  City of
# 276 San Lorenzo Valley Water District
# 277 Rialto  City of
# 278 Woodland  City of
# 279 Camrosa Water District
# 280 Laguna Beach County Water District
# 281 Santa Maria  City of
# 282 Los Angeles County Public Works Waterworks District 40
# 283 Glendora  City of
# 284 San Bernardino  City of
# 285 Valley of the Moon Water District
# 286 Soledad, City of
# 287 Menlo Park  City of
# 288 Palmdale Water District
# 289 Anaheim  City of
# 290 Mammoth Community Water District
# 291 Porterville  City of
# 292 Golden State Water Company San Dimas
# 293 Triunfo Sanitation District / Oak Park Water Service
# 294 Sunnyslope County Water District
# 295 Vallecitos Water District
# 296 Casitas Municipal Water District
# 297 Watsonville  City of
# 298 Linda County Water District
# 299 San Jose Water Company
# 300 Coachella Valley Water District
# 301 Kingsburg, City of
# 302 Rosamond Community Service District
# 303 Tulare, City of
# 304 Livingston  City of
# 305 Crescent City  City of
# 306 Fillmore  City of
# 307 Rainbow Municipal Water District
# Don't have complete data for water year 2016 for 'rainbow municipal water district', skipping...
# 308 Chino  City of
# 309 Huntington Park  City of
# 310 Garden Grove  City of
# 311 Pittsburg  City of
# 312 Yuba City  City of
# 313 Gilroy  City of
# 314 El Toro Water District
# 315 San Gabriel County Water District
# 316 Apple Valley Ranchos Water Company
# 317 Reedley  City of
# 318 Elsinore Valley Municipal Water District
# 319 Riverside Highland Water Company
# 320 California Water Service Company Dixon, City of
# 321 Paradise Irrigation District
# 322 San Juan Capistrano  City of
# 323 California Water Service Company Stockton
# 324 Camarillo  City of
# 325 Golden State Water Company Placentia
# 326 Golden State Water Company Bell-Bell Gardens
# 327 Sacramento  City of
# 328 Brea  City of
# 329 Golden State Water Company Barstow
# 330 Roseville  City of
# Don't have complete data for water year 2016 for 'roseville  city of', skipping...
# 331 Sunny Slope Water Company
# 332 Calexico  City of
# Don't have complete data for water year 2016 for 'calexico  city of', skipping...
# 333 Orange  City of
# 334 San Jacinto  City of
# 335 Sacramento Suburban Water District
# 336 Hawthorne  City of
# 337 Norwalk City of
# 338 California Water Service Company Dominguez
# 339 Torrance  City of
# Don't have complete data for water year 2016 for 'torrance  city of', skipping...
# 340 City of Newman Water Department
# Can't find supplier ID for 'city of newman water department', skipping...
# 341 Sanger  City of
# 342 Fallbrook Public Utility District
# 343 California Water Service Company Palos Verdes
# 344 Redding  City of
# 345 Valencia Water Company
# 346 Golden State Water Company Culver City
# 347 Ceres  City of
# 348 El Segundo  City of
# 349 Manhattan Beach  City of
# 350 South Pasadena  City of
# 351 Dinuba  City of
# Don't have complete data for water year 2016 for 'dinuba  city of', skipping...
# 352 El Centro  City of
# 353 Rincon Del Diablo Municipal Water District
# 354 Redwood City  City of
# 355 Hesperia Water District City of
# 356 Nevada Irrigation District
# 357 Desert Water Agency
# 358 Las Virgenes Municipal Water District
# 359 Mesa Water District
# Can't find supplier ID for 'mesa water district', skipping...
# 360 Modesto, City of
# 361 San Jose  City of
# 362 Exeter  City of
# 363 Lomita  City of
# 364 Lynwood  City of
# Don't have complete data for water year 2016 for 'lynwood  city of', skipping...
# 365 Vacaville  City of
# Don't have complete data for water year 2016 for 'vacaville  city of', skipping...
# 366 Monterey Park  City of
# 367 Brawley  City of
# 368 Rio Linda - Elverta Community Water District
# 369 Stockton  City of
# 370 Rancho California Water District
# 371 Shasta Lake  City of
# 372 Santa Monica  City of
# 373 Humboldt Community Service District
# 374 Cambria Community Services District
# 375 Otay Water District
# 376 Covina  City of
# Can't find supplier ID for 'covina  city of ', skipping...
# 377 Nipomo Community Services District
# 378 Banning  City of
# 379 Indio  City of
# 380 La Habra  City of Public Works
# 381 Blythe  City of
# 382 Alhambra  City of
# 383 San Bernardino County Service Area 70J
# Can't find supplier ID for 'san bernardino county service area 70j', skipping...
# 384 East Valley Water District
# 385 Perris, City of
# 386 Montebello Land and Water Company
# 387 Goleta Water District
# 388 Fortuna  City of
# 389 South Feather Water and Power Agency
# Don't have complete data for water year 2016 for 'south feather water and power agency', skipping...
# 390 Fair Oaks Water District
# 391 Lakewood  City of
# 392 Georgetown Divide Public Utilities District
# 393 Los Angeles County Public Works Waterworks District 29
# 394 Helix Water District
# 395 Fairfield  City of
# 396 Crestline Village Water District
# 397 Yucaipa Valley Water District
# 398 Padre Dam Municipal Water District
# 399 Wasco  City of
# 400 Upland  City of
# 401 Susanville  City of
# Don't have complete data for water year 2016 for 'susanville  city of', skipping...
# 402 Chino Hills  City of
# 403 Huntington Beach  City of
# 404 Great Oaks Water Company Incorporated
# 405 Coalinga City of
# Can't find supplier ID for 'coalinga city of', skipping...
# 406 Quartz Hill Water District
# 407 San Gabriel Valley Water Company

# %%
js[provider_id_lookup['East Bay Municipal Utilities District'.lower()]]
# Out:
# {'agencyName': 'east bay municipal utilities district',
#  'annualTarget': 55827386207.0,
#  'monthlyPrediction': {'01': 2417.0425868076827,
#   '02': 2307.3946062486384,
#   '03': 2162.496771084676,
#   '04': 2569.9142125418007,
#   '05': 3744.794391501367,
#   '06': 4781.496866924954,
#   '07': 5052.842907325889,
#   '08': 4874.674539013777,
#   '09': 4451.649133761039,
#   '10': 2885.1000277823123,
#   '11': 2555.6796736092665,
#   '12': 2564.2099279337895},
#  'totalUsage': {'2014-06': 4786.015037593985,
#   '2014-07': 4954.962406015037,
#   '2014-08': 4511.965192168238,
#   '2014-09': 4121.02973168963,
#   '2014-10': 3894.5612762871647,
#   '2014-11': 3042.3495286439447,
#   '2014-12': 2783.901377810007,
#   '2015-01': 2946.906474820144,
#   '2015-02': 2709.2805755395684,
#   '2015-03': 3345.4676258992804,
#   '2015-04': 3206.4028776978416,
#   '2015-05': 3350.863309352518,
#   '2015-06': 3437.5539568345325,
#   '2015-07': 3703.956834532374,
#   '2015-08': 3777.338129496403,
#   '2015-09': 3640.7913669064747,
#   '2015-10': 3511.5107913669067,
#   '2015-11': 2788.4172661870502,
#   '2015-12': 2671.798561151079,
#   '2016-01': 2668.8571428571427,
#   '2016-02': 2500.275862142857,
#   '2016-03': 2689.714285714286,
#   '2016-04': 2870.5714285714284,
#   '2016-05': 3542.3571428571427,
#   '2016-06': 4054.214285714286,
#   '2016-07': 4326.142857142857,
#   '2016-08': 4291.071428571428,
#   '2016-09': 4025.8571428571427,
#   '2016-10': 3182.932591452504},
#  'usageByCategory': {'commercialIndustrialPerCapita': {'2014-06': 0.0,
#    '2014-07': 0.0,
#    '2014-08': 0.0,
#    '2014-09': 0.0,
#    '2014-10': 0.0,
#    '2014-11': 0.0,
#    '2014-12': 0.0,
#    '2015-01': 0.0,
#    '2015-02': 0.0,
#    '2015-03': 0.0,
#    '2015-04': 0.0,
#    '2015-05': 0.0,
#    '2015-06': 653.8129496402878,
#    '2015-07': 687.0503597122303,
#    '2015-08': 717.410071942446,
#    '2015-09': 720.5035971223022,
#    '2015-10': 715.8273381294964,
#    '2015-11': 609.3525179856115,
#    '2015-12': 606.4748201438849,
#    '2016-01': 857.8571428571429,
#    '2016-02': 564.1379310714286,
#    '2016-03': 578.5714285714286,
#    '2016-04': 592.8571428571429,
#    '2016-05': 682.1428571428571,
#    '2016-06': 599.2857142857143,
#    '2016-07': 710.0,
#    '2016-08': 815.0,
#    '2016-09': 651.4285714285714,
#    '2016-10': 648.8461234368451},
#   'otherPotablePerCapita': {'2014-06': 1483.6646616541354,
#    '2014-07': 1536.0383458646618,
#    '2014-08': 1759.6664249456128,
#    '2014-09': 1607.2015953589557,
#    '2014-10': 1557.8245105148658,
#    '2014-11': 1186.5163161711384,
#    '2014-12': 1057.8825235678028,
#    '2015-01': 1119.8244604316546,
#    '2015-02': 1056.6194244604317,
#    '2015-03': 1304.7323741007194,
#    '2015-04': 1218.4330935251799,
#    '2015-05': 1340.3453237410072,
#    '2015-06': 686.8330935251798,
#    '2015-07': 794.5323741007194,
#    '2015-08': 755.7517985611511,
#    '2015-09': 699.405035971223,
#    '2015-10': 688.7769784172662,
#    '2015-11': 478.13021582733813,
#    '2015-12': 408.8086330935252,
#    '2016-01': 156.30857142857144,
#    '2016-02': 410.9696551642857,
#    '2016-03': 470.41714285714284,
#    '2016-04': 497.96,
#    '2016-05': 734.8,
#    '2016-06': 981.8578571428571,
#    '2016-07': 1020.4571428571429,
#    '2016-08': 858.5178571428571,
#    '2016-09': 918.6557142857143,
#    '2016-10': 624.3269131441563},
#   'residentialPerCapita': {'2014-06': 3302.3503759398495,
#    '2014-07': 3418.924060150376,
#    '2014-08': 2752.298767222625,
#    '2014-09': 2513.8281363306746,
#    '2014-10': 2336.736765772299,
#    '2014-11': 1855.8332124728063,
#    '2014-12': 1726.0188542422045,
#    '2015-01': 1827.0820143884891,
#    '2015-02': 1652.6611510791367,
#    '2015-03': 2040.7352517985612,
#    '2015-04': 1987.9697841726618,
#    '2015-05': 2010.5179856115108,
#    '2015-06': 2096.907913669065,
#    '2015-07': 2222.3741007194244,
#    '2015-08': 2304.1762589928057,
#    '2015-09': 2220.8827338129495,
#    '2015-10': 2106.906474820144,
#    '2015-11': 1700.9345323741006,
#    '2015-12': 1656.515107913669,
#    '2016-01': 1654.6914285714286,
#    '2016-02': 1525.1682759071427,
#    '2016-03': 1640.7257142857143,
#    '2016-04': 1779.7542857142857,
#    '2016-05': 2125.4142857142856,
#    '2016-06': 2473.070714285714,
#    '2016-07': 2595.6857142857143,
#    '2016-08': 2617.5535714285716,
#    '2016-09': 2455.772857142857,
#    '2016-10': 1909.7595548715021}}}

# %%
with open(DATA_DIR + 'usage.json', 'w') as f:
    f.write(json.dumps(js, indent=4))
