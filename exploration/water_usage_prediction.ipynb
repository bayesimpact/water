# %% [markdown]
# # Produce `water_data.json` for the app's use
#
# Authors: everett@bayes.org, mehdi@bayes.org

# %%
from collections import defaultdict
import datetime as datetime
import json
import random

import numpy as np
import pandas as pd

# %matplotlib inline

DATA_DIR = "../data/"

# %% [markdown]
# ### Load a reduced version of the water conservation dataset
#
# #### This was manually edited by me (Everett) from the full dataset (also in the same folder), though in an ideal world I'd do it via a Makefile and code.

# %%
df = pd.read_csv(DATA_DIR + "uw_supplier_data110116_edited.csv", encoding="latin-1")
df = df.rename(columns=dict((c, c.strip()) for c in df.columns))
print("* " + "\n* ".join(df.columns))
# Out:
# * Supplier Name
# * Mandatory Restrictions
# * Reporting Month
# * Total Population Served
# * Conservation Standard (starting in June 2015) *Adjusted in March 2016 **Revised in June 2016
# * REPORTED Total Monthly Potable Water Production Reporting Month
# * REPORTED Monthly CII
# * REPORTED Monthly Ag Use Reporting Month
# * CALCULATED Total Monthly Potable Water Production Reporting Month Gallons
# * CALCULATED Total Monthly Potable Water Production 2013 Gallons
# * CALCULATED Monthly CII Reporting Month
# * CALCULATED R-GPCD Reporting Month
# * % Residential Use
# * Hydrologic Region

# %%
def numberize(i):
    """Convert a string like '100,000' into a float, like 100000.0
    
    Since this data has a lot of variants for zero (missing data,
    null, strings like 'n/a'), we regard any failed float conversion
    as an indicator that the value is 0. This seems to be correct
    based on examining the data.
    """
    try:
        return float(str(i).replace(',', ''))
    except:
        return 0.0

# %%
# Rename wordy columns to more palatable strings
col_rename_dict = {
    'Supplier Name': 'supplier_name',
#     'REPORTED Total Monthly Potable Water Production Reporting Month': 'reported_total_gal',
#     'REPORTED Monthly CII': 'reported_cii_gal',
#     'REPORTED Monthly Ag Use Reporting Month': 'reported_ag_gal',
    "CALCULATED Total Monthly Potable Water Production Reporting Month Gallons": "total_potable_gal",
    "CALCULATED Total Monthly Potable Water Production 2013 Gallons": "total_potable_gal_2013",
    "CALCULATED Monthly CII Reporting Month": "cii_gal",
#     "CALCULATED R-GPCD Reporting Month": "r_gpcd",
    'Reporting Month': 'reporting_month',
    'Total Population Served': 'total_population_served',
    'REPORTED Residential Gallons-per-Capita-Day (R-GPCD) (starting in September 2014)': 'r_gpc',
    '% Residential Use': 'percent_residential_use',
    'Hydrologic Region': 'hydrologic_region',
    'Conservation Standard (starting in June 2015) *Adjusted in March 2016 **Revised in June 2016': 'conservation_standard'
}
cols = list(df.columns)
for c in cols:
    if c not in col_rename_dict:
        del df[c]
df = df.rename(columns=col_rename_dict)

# %%
# Compute a bunch of useful columns. Water usage breakdowns, etc.

df['reporting_month'] = pd.to_datetime(df['reporting_month'])
df['month'] = df['reporting_month'].apply(lambda x: x.month)
df['year'] = df['reporting_month'].apply(lambda x: x.year)
df['water_year'] = df['year'] + (df['month'] > 9).astype(int)

# Weirdly, the "total potable water REPORTED" number includes agricultural
# water, whereas the "total potable gallons CALCULATED" does not. The former
# is also reported in a range of units, while the latter converts to gallons.

df['residential_gal'] = df['total_potable_gal'] * (df['percent_residential_use'] / 100.0)
df['cii_gal'] = df['cii_gal'].apply(numberize)
df['other_gal'] = df['total_potable_gal'] * (1 - df['percent_residential_use'] / 100.0) - df['cii_gal']

df['conservation_standard'] = df['conservation_standard'].apply(
    lambda s: 0.0 if pd.isnull(s) else float(s.strip('%')) / 100.0)

df.head()
# Out:
#                            supplier_name reporting_month  \
# 0  East Bay Municipal Utilities District      2016-09-15
# 1  East Bay Municipal Utilities District      2016-08-15
# 2  East Bay Municipal Utilities District      2016-07-15
# 3  East Bay Municipal Utilities District      2016-06-15
# 4  East Bay Municipal Utilities District      2016-05-15
#
#    total_population_served  conservation_standard  total_potable_gal  \
# 0                  1400000                   0.00         5636200000
# 1                  1400000                   0.00         6007500000
# 2                  1400000                   0.00         6056600000
# 3                  1400000                   0.00         5675900000
# 4                  1400000                   0.16         4959300000
#
#    total_potable_gal_2013     cii_gal  percent_residential_use  \
# 0              6528400000   912000000                       61
# 1              7172300000  1141000000                       61
# 2              7452200000   994000000                       60
# 3              6927500000   839000000                       61
# 4              6716500000   955000000                       60
#
#    hydrologic_region  month  year  water_year  residential_gal   other_gal
# 0  San Francisco Bay      9  2016        2016       3438082000  1286118000
# 1  San Francisco Bay      8  2016        2016       3664575000  1201925000
# 2  San Francisco Bay      7  2016        2016       3633960000  1428640000
# 3  San Francisco Bay      6  2016        2016       3462299000  1374601000
# 4  San Francisco Bay      5  2016        2016       2975580000  1028720000

# %%
def computeUsage(df):
    '''Given a dataframe for a single provider, create usage dict.'''
    usage = defaultdict(dict)
    for i, row in df.iterrows():
        m = row['reporting_month'].strftime('%Y-%m')
        pop = float(row['total_population_served'])
        usage['totalPerCapita'][m] = numberize(row['total_potable_gal']) / pop
        usage['residentialPerCapita'][m] = numberize(row['residential_gal']) / pop
        usage['commercialIndustrialPerCapita'][m] = numberize(row['cii_gal']) / pop
        usage['otherPotablePerCapita'][m] = numberize(row['other_gal']) / pop
    
    # For demonstration purposes, add fake data for Oct 2016.
    # Will swap with real data once it's available.
    reference_month = '2015-10'
    if '2015-10' not in usage['totalPerCapita']:
        reference_month = random.choice(list(usage['totalPerCapita'].keys()))
    factor = 1 + random.uniform(-0.1, 0.1)
    for k, v in usage.items():
        usage[k]['2016-10'] = usage[k][reference_month] * factor

    return dict(usage)  # Convert from defaultdict to regular dict

def computePredictions(usage):
    '''Compute monthly usage predictions for the upcoming 12 months.'''
    predictions = {}
    for month in range(1, 13):
        matching_keys = [k for k in usage if k.endswith("%02d" % month)]
        if len(matching_keys) == 0:
            # We have never seen data for this month, can't predict anything
            result = None
        elif len(matching_keys) == 1:
            # Only one occurance of this month, just predict homeostasis
            result = usage[matching_keys[0]]
        else:
            # Assume the year-over-year growth for this month is static.
            matching_keys.sort()
            growth = usage[matching_keys[-1]] / usage[matching_keys[-2]]
            result = usage[matching_keys[-1]] * growth
        predictions['%02d' %  month] = result
    return predictions

def computeTargetUsage(df, year):
    '''Given a dataframe for a single provider, calculate it's usage target for the year.'''
    if len(df[df['water_year'] == year]) < 12:
        print("Don't have complete data for water year %d, skipping..." % (year))
        return None
    reduction = df.loc[datetime.datetime(year - 1, 10, 15), 'conservation_standard']
    df_year = df[df['water_year'] == year]
    used_year = (df_year['total_potable_gal_2013'] / df_year['total_population_served']).sum()
    return (1 - reduction) * used_year

# %%
# One dataset identifies water suppliers by ID, the other merely by name. We need to pair them.

providers = pd.read_csv(DATA_DIR + 'provider_ids.tsv', sep='\t')
provider_id_lookup = {}
for p, i in zip(providers['Provider'], providers['ID']):
    provider_id_lookup[p.lower()] = i

# %%
js = {}
for i, items in enumerate(df.groupby("supplier_name").groups.items()):
    name, indices = items
    print(i, name)
    name = name.lower()
    if name not in provider_id_lookup:
        print("Can't find supplier ID for '%s', skipping..." % name)
        continue

    supplier_df = df.loc[indices].set_index('reporting_month', drop=False)
    usage = computeUsage(supplier_df)
    total = usage['totalPerCapita']
    del usage['totalPerCapita']
    preds = computePredictions(total)
    target_2016 = computeTargetUsage(supplier_df, 2016)
    target_2015 = computeTargetUsage(supplier_df, 2015)
    if target_2016 is None or target_2015 is None:
        continue

    js[provider_id_lookup[name]] = {
        "agencyName": name,
        "totalUsage": total,
        "usageByCategory": usage,
        "monthlyPrediction": preds,
        "annualTarget": target_2016,
        "previousTarget": target_2015,
    }
# Out:
# 0 Hollister  City of
# 1 California Water Service Company Antelope Valley
# 2 South Gate  City of
# 3 Lemoore  City of
# 4 Mesa Water District
# Can't find supplier ID for 'mesa water district', skipping...
# 5 West Sacramento  City of
# 6 Grover Beach  City of
# Don't have complete data for water year 2016, skipping...
# 7 Napa  City of
# 8 Joshua Basin Water District
# 9 Mid-Peninsula Water District
# 10 McKinleyville Community Service District
# 11 San Juan Water District
# 12 El Centro  City of
# 13 San Gabriel Valley Water Company
# 14 Fairfield  City of
# 15 Laguna Beach County Water District
# 16 Nevada Irrigation District
# 17 Valley of the Moon Water District
# 18 Manhattan Beach  City of
# 19 Georgetown Divide Public Utilities District
# 20 City of Newman Water Department
# Can't find supplier ID for 'city of newman water department', skipping...
# 21 San Bernardino County Service Area 64
# 22 Sweetwater Springs Water District
# 23 Oceanside  City of
# 24 Bella Vista Water District
# 25 Oxnard  City of
# 26 Atascadero Mutual Water Company
# 27 Santa Monica  City of
# 28 Brentwood  City of
# 29 Orchard Dale Water District
# 30 Ripon  City of
# 31 Beverly Hills  City of
# 32 Monte Vista Water District
# 33 Greenfield, City of
# 34 Wasco  City of
# 35 Patterson  City of
# 36 Valley Water Company
# 37 East Bay Municipal Utilities District
# 38 Los Angeles County Public Works Waterworks District 40
# 39 California Water Service Company Westlake
# 40 Golden State Water Company Barstow
# 41 Norwalk City of
# 42 South Coast Water District
# 43 Arroyo Grande  City of
# 44 Ceres  City of
# 45 Santa Fe Irrigation District
# 46 Golden State Water Company Artesia
# 47 San Buenaventura  City of
# 48 Valencia Water Company
# 49 Morgan Hill  City of
# Don't have complete data for water year 2015, skipping...
# 50 Thousand Oaks  City of
# 51 Sunny Slope Water Company
# 52 Anderson, City of
# Don't have complete data for water year 2016, skipping...
# Don't have complete data for water year 2015, skipping...
# 53 Brawley  City of
# 54 Walnut Valley Water District
# Don't have complete data for water year 2016, skipping...
# 55 Otay Water District
# 56 California-American Water Company Sacramento District
# 57 Cerritos  City of
# 58 Lake Hemet Municipal Water District
# 59 Palo Alto  City of
# 60 West Valley Water District
# 61 Olivehurst Public Utility District
# Can't find supplier ID for 'olivehurst public utility district', skipping...
# 62 California Water Service Company Marysville
# 63 Glendora  City of
# 64 Lathrop, City of
# Can't find supplier ID for 'lathrop, city of ', skipping...
# 65 California Water Service Company Dixon, City of
# 66 Fallbrook Public Utility District
# 67 Myoma Dunes Mutual Water Company
# 68 Discovery Bay Community Services District
# 69 Galt  City of
# 70 Nipomo Community Services District
# 71 Suisun-Solano Water Authority
# 72 Norco  City of
# 73 Golden State Water Company S Arcadia
# 74 Paso Robles  City of
# 75 Burlingame  City of
# 76 Sacramento County Water Agency
# 77 Port Hueneme  City of
# 78 Redding  City of
# 79 Orange Vale Water Company
# 80 Cloverdale
# Don't have complete data for water year 2016, skipping...
# Don't have complete data for water year 2015, skipping...
# 81 Lincoln  City of
# 82 Eastern Municipal Water District
# 83 Bakman Water Company
# 84 Lee Lake Water District
# 85 Dublin San Ramon Services District
# 86 Vallejo  City of
# 87 Ontario  City of
# 88 Contra Costa Water District
# 89 Santa Paula  City of
# 90 Bakersfield  City of
# 91 Soledad, City of
# 92 San Gabriel Valley Fontana Water Company
# 93 Calaveras County Water District
# 94 Burbank  City of
# 95 Sunnyslope County Water District
# 96 Fillmore  City of
# 97 East Orange County Water District
# Don't have complete data for water year 2016, skipping...
# 98 Lompoc  City of
# 99 Rainbow Municipal Water District
# Don't have complete data for water year 2016, skipping...
# 100 Lomita  City of
# 101 Los Banos, City of
# 102 California Water Service Company East Los Angeles
# 103 Pasadena  City of
# 104 Ukiah  City of
# Don't have complete data for water year 2016, skipping...
# 105 Lakewood  City of
# 106 Reedley  City of
# 107 Lakeside Water District
# 108 Whittier  City of
# 109 Gilroy  City of
# 110 La Palma  City of
# 111 Fullerton  City of
# 112 Coalinga City of
# Can't find supplier ID for 'coalinga city of', skipping...
# 113 Los Angeles County Public Works Waterworks District 29
# 114 Davis  City of
# 115 Marin Municipal Water District
# 116 Atwater  City of
# 117 El Toro Water District
# 118 Imperial, City of
# 119 Menlo Park  City of
# 120 Lodi  City of Public Works Department
# 121 Ramona Municipal Water District
# 122 Lamont Public Utility District
# 123 Bellflower-Somerset Mutual Water Company
# 124 Riverside  City of
# 125 Cucamonga Valley Water District
# 126 California Water Service Company Bakersfield
# 127 Anaheim  City of
# 128 Santa Fe Springs  City of
# 129 Moulton Niguel Water District
# 130 Indian Wells Valley Water District
# 131 Sanger  City of
# 132 Tustin  City of
# 133 Paramount  City of
# 134 San Francisco Public Utilities Commission
# 135 Vista Irrigation District
# 136 Shafter  City of
# 137 Pinedale County Water District
# 138 Pico Rivera  City of
# 139 San Dieguito Water District
# 140 Cambria Community Services District
# 141 Rialto  City of
# 142 Golden State Water Company Bell-Bell Gardens
# 143 San Juan Capistrano  City of
# 144 Golden State Water Company Cordova
# 145 El Dorado Irrigation District
# 146 Martinez  City of
# 147 Redwood City  City of
# 148 Santa Margarita Water District
# 149 Buena Park  City of
# 150 Hayward  City of
# 151 Vacaville  City of
# Don't have complete data for water year 2016, skipping...
# Don't have complete data for water year 2015, skipping...
# 152 Livingston  City of
# 153 Millbrae  City of
# 154 Amador Water Agency
# 155 Park Water Company
# 156 Golden State Water Company San Dimas
# 157 Chino  City of
# 158 San Lorenzo Valley Water District
# Don't have complete data for water year 2015, skipping...
# 159 Tuolumne Utilities District
# 160 Santa Ana  City of
# 161 Madera  City of
# 162 Arvin Community Services District
# 163 Pleasanton  City of
# 164 Las Virgenes Municipal Water District
# 165 Susanville  City of
# Don't have complete data for water year 2016, skipping...
# 166 Santa Maria  City of
# 167 City of Big Bear Lake, Dept of Water & Power
# Can't find supplier ID for 'city of big bear lake, dept of water & power', skipping...
# 168 Rubio Canyon Land and Water Association
# 169 Calexico  City of
# Don't have complete data for water year 2016, skipping...
# 170 Kingsburg, City of
# 171 Benicia  City of
# 172 Coachella  City of
# 173 Victorville Water District
# 174 San Jacinto  City of
# 175 California-American Water Ventura District
# 176 Healdsburg  City of
# 177 Shasta Lake  City of
# 178 Huntington Park  City of
# 179 Golden State Water Company Southwest
# 180 Rosamond Community Service District
# 181 Golden State Water Company Bay Point
# 182 California City  City of
# 183 Hillsborough  Town of
# 184 Brea  City of
# 185 Arcadia  City of
# Don't have complete data for water year 2016, skipping...
# 186 Rubidoux Community Service District
# 187 Torrance  City of
# Don't have complete data for water year 2016, skipping...
# 188 North Coast County Water District
# 189 Merced  City of
# 190 Irvine Ranch Water District
# 191 San Clemente  City of
# 192 California Water Service Company Visalia
# 193 Carlsbad Municipal Water District
# 194 Arcata  City of
# 195 Mountain View  City of
# 196 Compton  City of
# 197 Hawthorne  City of
# 198 Hanford  City of
# 199 Casitas Municipal Water District
# 200 Morro Bay  City of
# 201 Santa Barbara  City of
# 202 Seal Beach  City of
# 203 Golden State Water Company S San Gabriel
# 204 Roseville  City of
# Don't have complete data for water year 2016, skipping...
# 205 Fortuna  City of
# 206 Desert Water Agency
# 207 Vallecitos Water District
# 208 Riverbank  City of
# 209 Escondido  City of
# 210 Western Municipal Water District of Riverside
# 211 Blythe  City of
# 212 California Water Service Company Stockton
# 213 Milpitas  City of
# 214 Montecito Water District
# 215 Vaughn Water Company
# 216 Crescenta Valley Water District
# 217 Mission Springs Water District
# Don't have complete data for water year 2016, skipping...
# 218 California Water Service Company Salinas District
# 219 California Water Service Company King City
# 220 Rowland Water District
# 221 Mountain House Community Services District
# Can't find supplier ID for 'mountain house community services district', skipping...
# 222 Truckee-Donner Public Utilities District
# 223 Groveland Community Services District
# 224 Glendale  City of
# 225 Elk Grove Water Service
# 226 Sacramento  City of
# 227 California Water Service Company Livermore
# 228 Placer County Water Agency
# 229 South Pasadena  City of
# Don't have complete data for water year 2015, skipping...
# 230 Perris, City of
# 231 Lake Arrowhead Community Services District
# 232 Kerman, City of
# Don't have complete data for water year 2015, skipping...
# 233 Upland  City of
# 234 North Marin Water District
# 235 Monterey Park  City of
# 236 Yucaipa Valley Water District
# 237 Westborough Water District
# 238 Goleta Water District
# 239 Linda County Water District
# 240 San Jose Water Company
# 241 Sierra Madre  City of
# Don't have complete data for water year 2015, skipping...
# 242 Golden State Water Company Placentia
# 243 Redlands  City of
# 244 Olivenhain Municipal Water District
# 245 Yuba City  City of
# 246 Sacramento Suburban Water District
# 247 Diablo Water District
# 248 Westminster  City of
# 249 Delano  City of
# 250 Adelanto City of
# 251 Helix Water District
# 252 Rio Vista, city of
# 253 Phelan Pinon Hills Community Services District
# 254 North Tahoe Public Utility District
# 255 California-American Water Company Monterey District
# 256 Los Angeles Department of Water and Power
# 257 San Jose  City of
# 258 Huntington Beach  City of
# 259 Modesto, City of
# 260 Golden State Water Company Simi Valley
# 261 El Monte  City of
# 262 Newport Beach  City of
# 263 Padre Dam Municipal Water District
# 264 Estero Municipal Improvement District
# 265 Golden State Water Company Florence Graham
# 266 Hi-Desert Water District
# Don't have complete data for water year 2016, skipping...
# 267 Rancho California Water District
# 268 California-American Water Company Los Angeles District
# 269 California Water Service Company Chico District
# 270 Sonoma  City of
# 271 Monrovia  City of
# Don't have complete data for water year 2016, skipping...
# 272 Colton, City of
# 273 Porterville  City of
# 274 Poway  City of
# 275 Golden State Water Company Orcutt
# 276 Quartz Hill Water District
# 277 California Water Service Company Willows
# 278 San Bruno  City of
# 279 Newhall County Water District
# 280 Triunfo Sanitation District / Oak Park Water Service
# 281 Twentynine Palms Water District
# 282 Folsom  City of
# 283 California Water Service Company Oroville
# 284 Elsinore Valley Municipal Water District
# 285 West Kern Water District
# 286 San Bernardino  City of
# 287 Turlock  City of
# 288 Dinuba  City of
# Don't have complete data for water year 2016, skipping...
# 289 Orange  City of
# 290 Yorba Linda Water District
# 291 Fountain Valley  City of
# 292 Oakdale  City of
# 293 Tracy  City of
# 294 Big Bear City Community Services District
# Can't find supplier ID for 'big bear city community services district', skipping...
# 295 Palmdale Water District
# 296 Pico Water District
# 297 Fair Oaks Water District
# 298 Hemet  City of
# 299 Pomona  City of
# 300 Golden State Water Company Claremont
# 301 Long Beach  City of
# 302 Valley Center Municipal Water District
# 303 California Water Service Company Mid Peninsula
# 304 Crestline Village Water District
# 305 Citrus Heights Water District
# 306 Trabuco Canyon Water District
# 307 Exeter  City of
# 308 Suburban Water Systems Whittier/La Mirada
# 309 Riverside Highland Water Company
# 310 Garden Grove  City of
# 311 Santa Rosa  City of
# 312 Golden State Water Company West Orange
# 313 San Bernardino County Service Area 70J
# Can't find supplier ID for 'san bernardino county service area 70j', skipping...
# 314 Jurupa Community Service District
# 315 Paradise Irrigation District
# 316 Valley County Water District
# 317 Rincon Del Diablo Municipal Water District
# 318 California-American Water Company San Diego District
# 319 San Fernando  City of
# 320 Windsor, Town of
# 321 East Palo Alto, City of
# 322 Sunnyvale  City of
# 323 Petaluma  City of
# 324 Crescent City  City of
# 325 El Segundo  City of
# 326 Alco Water Service
# 327 Lincoln Avenue Water Company
# 328 Stockton  City of
# 329 Marina Coast Water District
# 330 Coachella Valley Water District
# 331 Humboldt Community Service District
# 332 Tahoe City Public Utilities District
# 333 South Feather Water and Power Agency
# Don't have complete data for water year 2016, skipping...
# 334 California Water Service Company Hermosa/Redondo
# 335 Banning  City of
# 336 Scotts Valley Water District
# 337 Hesperia Water District City of
# 338 California Water Service Company Selma
# 339 Corona  City of
# 340 Beaumont-Cherry Valley Water District
# 341 California Water Service Company Dominguez
# 342 Woodland  City of
# 343 Corcoran, City of
# Can't find supplier ID for 'corcoran, city of', skipping...
# 344 California Water Service Company South San Francisco
# 345 Alhambra  City of
# 346 Livermore  City of Division of Water Resources
# 347 Suburban Water Systems San Jose Hills
# 348 San Luis Obispo  City of
# 349 Soquel Creek Water District
# 350 Castaic Lake Water Agency Santa Clarita Water Division
# 351 Golden State Water Company Culver City
# 352 Covina  City of
# Can't find supplier ID for 'covina  city of ', skipping...
# 353 Pismo Beach  City of
# 354 Azusa  City of
# 355 Tulare, City of
# 356 Eureka  City of
# 357 Carpinteria Valley Water District
# 358 Tehachapi, City of
# 359 Camarillo  City of
# 360 California Water Service Company Los Altos/Suburban
# 361 Red Bluff  City of
# 362 American Canyon, City of
# 363 Santa Clara  City of
# 364 Carmichael Water District
# 365 Oildale Mutual Water Company
# 366 San Diego  City of
# 367 Fresno  City of
# 368 Antioch  City of
# 369 Great Oaks Water Company Incorporated
# 370 Coastside County Water District
# 371 Clovis  City of
# 372 Humboldt Bay Municipal Water District
# 373 Indio  City of
# 374 Sweetwater Authority
# 375 La Habra  City of Public Works
# 376 Alameda County Water District
# 377 California Water Service Company Kern River Valley
# 378 Golden State Water Company Norwalk
# 379 East Valley Water District
# 380 San Gabriel County Water District
# 381 Chino Hills  City of
# 382 Lynwood  City of
# Don't have complete data for water year 2016, skipping...
# 383 Ventura County Waterworks District No. 8
# 384 Montebello Land and Water Company
# 385 Pittsburg  City of
# 386 Daly City  City of
# 387 California Water Service Company Bear Gulch
# 388 South Tahoe Public Utilities District
# 389 Manteca  City of
# 390 Yreka, City of
# 391 California Water Service Company Palos Verdes
# 392 La Verne  City of
# 393 Del Oro Water Company
# 394 Rohnert Park  City of
# 395 Downey  City of
# 396 Inglewood  City of
# 397 California Water Service Company Redwood Valley
# 398 Fruitridge Vista Water Company
# 399 Watsonville  City of
# 400 Rio Linda - Elverta Community Water District
# 401 East Niles Community Service District
# 402 Mammoth Community Water District
# 403 Camrosa Water District
# 404 Apple Valley Ranchos Water Company
# 405 Loma Linda  City of *
# Can't find supplier ID for 'loma linda  city of *', skipping...
# 406 Santa Cruz  City of
# 407 Ventura County Waterworks District No 1

# %%
js[provider_id_lookup['East Bay Municipal Utilities District'.lower()]]
# Out:
# {'agencyName': 'east bay municipal utilities district',
#  'annualTarget': 41681.397410071942,
#  'monthlyPrediction': {'01': 2417.0425868076827,
#   '02': 2307.3946062486384,
#   '03': 2162.496771084676,
#   '04': 2569.9142125418007,
#   '05': 3744.794391501367,
#   '06': 4781.496866924954,
#   '07': 5052.842907325889,
#   '08': 4874.674539013777,
#   '09': 4451.649133761039,
#   '10': 3913.7824869663878,
#   '11': 2555.6796736092665,
#   '12': 2564.2099279337895},
#  'previousTarget': 49986.756329526652,
#  'totalUsage': {'2014-06': 4786.015037593985,
#   '2014-07': 4954.962406015037,
#   '2014-08': 4511.965192168238,
#   '2014-09': 4121.02973168963,
#   '2014-10': 3894.5612762871647,
#   '2014-11': 3042.3495286439447,
#   '2014-12': 2783.901377810007,
#   '2015-01': 2946.906474820144,
#   '2015-02': 2709.2805755395684,
#   '2015-03': 3345.4676258992804,
#   '2015-04': 3206.4028776978416,
#   '2015-05': 3350.863309352518,
#   '2015-06': 3437.5539568345325,
#   '2015-07': 3703.956834532374,
#   '2015-08': 3777.338129496403,
#   '2015-09': 3640.7913669064747,
#   '2015-10': 3511.5107913669067,
#   '2015-11': 2788.4172661870502,
#   '2015-12': 2671.798561151079,
#   '2016-01': 2668.8571428571427,
#   '2016-02': 2500.275862142857,
#   '2016-03': 2689.714285714286,
#   '2016-04': 2870.5714285714284,
#   '2016-05': 3542.3571428571427,
#   '2016-06': 4054.214285714286,
#   '2016-07': 4326.142857142857,
#   '2016-08': 4291.071428571428,
#   '2016-09': 4025.8571428571427,
#   '2016-10': 3707.1942811303106},
#  'usageByCategory': {'commercialIndustrialPerCapita': {'2014-06': 0.0,
#    '2014-07': 0.0,
#    '2014-08': 0.0,
#    '2014-09': 0.0,
#    '2014-10': 0.0,
#    '2014-11': 0.0,
#    '2014-12': 0.0,
#    '2015-01': 0.0,
#    '2015-02': 0.0,
#    '2015-03': 0.0,
#    '2015-04': 0.0,
#    '2015-05': 0.0,
#    '2015-06': 653.8129496402878,
#    '2015-07': 687.0503597122303,
#    '2015-08': 717.410071942446,
#    '2015-09': 720.5035971223022,
#    '2015-10': 715.8273381294964,
#    '2015-11': 609.3525179856115,
#    '2015-12': 606.4748201438849,
#    '2016-01': 857.8571428571429,
#    '2016-02': 564.1379310714286,
#    '2016-03': 578.5714285714286,
#    '2016-04': 592.8571428571429,
#    '2016-05': 682.1428571428571,
#    '2016-06': 599.2857142857143,
#    '2016-07': 710.0,
#    '2016-08': 815.0,
#    '2016-09': 651.4285714285714,
#    '2016-10': 755.7177442582788},
#   'otherPotablePerCapita': {'2014-06': 1483.6646616541354,
#    '2014-07': 1536.0383458646618,
#    '2014-08': 1759.6664249456128,
#    '2014-09': 1607.2015953589557,
#    '2014-10': 1557.8245105148658,
#    '2014-11': 1186.5163161711384,
#    '2014-12': 1057.8825235678028,
#    '2015-01': 1119.8244604316546,
#    '2015-02': 1056.6194244604317,
#    '2015-03': 1304.7323741007194,
#    '2015-04': 1218.4330935251799,
#    '2015-05': 1340.3453237410072,
#    '2015-06': 686.8330935251798,
#    '2015-07': 794.5323741007194,
#    '2015-08': 755.7517985611511,
#    '2015-09': 699.405035971223,
#    '2015-10': 688.7769784172662,
#    '2015-11': 478.13021582733813,
#    '2015-12': 408.8086330935252,
#    '2016-01': 156.30857142857144,
#    '2016-02': 410.9696551642857,
#    '2016-03': 470.41714285714284,
#    '2016-04': 497.96,
#    '2016-05': 734.8,
#    '2016-06': 981.8578571428571,
#    '2016-07': 1020.4571428571429,
#    '2016-08': 858.5178571428571,
#    '2016-09': 918.6557142857143,
#    '2016-10': 727.1599681938453},
#   'residentialPerCapita': {'2014-06': 3302.3503759398495,
#    '2014-07': 3418.924060150376,
#    '2014-08': 2752.298767222625,
#    '2014-09': 2513.8281363306746,
#    '2014-10': 2336.736765772299,
#    '2014-11': 1855.8332124728063,
#    '2014-12': 1726.0188542422045,
#    '2015-01': 1827.0820143884891,
#    '2015-02': 1652.6611510791367,
#    '2015-03': 2040.7352517985612,
#    '2015-04': 1987.9697841726618,
#    '2015-05': 2010.5179856115108,
#    '2015-06': 2096.907913669065,
#    '2015-07': 2222.3741007194244,
#    '2015-08': 2304.1762589928057,
#    '2015-09': 2220.8827338129495,
#    '2015-10': 2106.906474820144,
#    '2015-11': 1700.9345323741006,
#    '2015-12': 1656.515107913669,
#    '2016-01': 1654.6914285714286,
#    '2016-02': 1525.1682759071427,
#    '2016-03': 1640.7257142857143,
#    '2016-04': 1779.7542857142857,
#    '2016-05': 2125.4142857142856,
#    '2016-06': 2473.070714285714,
#    '2016-07': 2595.6857142857143,
#    '2016-08': 2617.5535714285716,
#    '2016-09': 2455.772857142857,
#    '2016-10': 2224.3165686781863}}}

# %%
with open(DATA_DIR + 'usage.json', 'w') as f:
    f.write(json.dumps(js, indent=4))
