# %% [markdown]
# # Produce `water_data.json` for the app's use
#
# Authors: everett@bayes.org, mehdi@bayes.org

# %%
from collections import defaultdict
import datetime as datetime
import json
import random

import numpy as np
import pandas as pd

# %matplotlib inline

DATA_DIR = "../data/"

# %% [markdown]
# ### Load a reduced version of the water conservation dataset
#
# #### This was manually edited by me (Everett) from the full dataset (also in the same folder), though in an ideal world I'd do it via a Makefile and code.

# %%
df = pd.read_csv(DATA_DIR + 'uw_supplier_data1201616_edited.csv', encoding="latin-1")
df = df.rename(columns=dict((c, c.strip()) for c in df.columns))
print("* " + "\n* ".join(df.columns))
df.head()
# Out:
# * Supplier Name
# * Mandatory Restrictions
# * Reporting Month
# * Total Population Served
# * REPORTED Total Monthly Potable Water Production Reporting Month
# * REPORTED Total Monthly Potable Water Production 2013
# * REPORTED Monthly CII
# * REPORTED Monthly Ag Use Reporting Month
# * Conservation Standard (starting in June 2015) *Adjusted in March 2016 **Revised in June 2016
# * CALCULATED Total Monthly Potable Water Production Reporting Month Gallons
# * CALCULATED Total Monthly Potable Water Production 2013 Gallons
# * CALCULATED Monthly CII Reporting Month
# * % Residential Use
# * Hydrologic Region
#                            Supplier Name Mandatory Restrictions  \
# 0  East Bay Municipal Utilities District                     No
# 1  East Bay Municipal Utilities District                     No
# 2  East Bay Municipal Utilities District                     No
# 3  East Bay Municipal Utilities District                     No
# 4  East Bay Municipal Utilities District                    Yes
#
#   Reporting Month Total Population Served  \
# 0        10/15/16              1,400,000
# 1         9/15/16              1,400,000
# 2         8/15/16              1,400,000
# 3         7/15/16              1,400,000
# 4         6/15/16              1,400,000
#
#    REPORTED Total Monthly Potable Water Production Reporting Month  \
# 0                                             4689.9
# 1                                             5636.2
# 2                                             6007.5
# 3                                             6056.6
# 4                                             5675.9
#
#    REPORTED Total Monthly Potable Water Production 2013 REPORTED Monthly CII  \
# 0                                             6175.0                     956
# 1                                             6528.4                     912
# 2                                             7172.3                    1141
# 3                                             7452.2                     994
# 4                                             6927.5                     839
#
#   REPORTED Monthly Ag Use Reporting Month  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   Conservation Standard (starting in June 2015) *Adjusted in March 2016 **Revised in June 2016  \
# 0                                                 0%
# 1                                                 0%
# 2                                                 0%
# 3                                                 0%
# 4                                                 0%
#
#   CALCULATED Total Monthly Potable Water Production Reporting Month Gallons  \
# 0                                     4,689,900,000
# 1                                     5,636,200,000
# 2                                     6,007,500,000
# 3                                     6,056,600,000
# 4                                     5,675,900,000
#
#   CALCULATED Total Monthly Potable Water Production 2013 Gallons  \
# 0                                     6,175,000,000
# 1                                     6,528,400,000
# 2                                     7,172,300,000
# 3                                     7,452,200,000
# 4                                     6,927,500,000
#
#   CALCULATED Monthly CII Reporting Month  % Residential Use  Hydrologic Region
# 0                           956,000,000                  60  San Francisco Bay
# 1                           912,000,000                  61  San Francisco Bay
# 2                         1,141,000,000                  61  San Francisco Bay
# 3                           994,000,000                  60  San Francisco Bay
# 4                           839,000,000                  61  San Francisco Bay

# %%
def numberize(i):
    """Convert a string like '100,000' into a float, like 100000.0
    
    Since this data has a lot of variants for zero (missing data,
    null, strings like 'n/a'), we regard any failed float conversion
    as an indicator that the value is 0. This seems to be correct
    based on examining the data.
    """
    try:
        return float(str(i).replace(',', ''))
    except:
        return 0.0

# %%
# Rename wordy columns to more palatable strings
col_rename_dict = {
    'Supplier Name': 'supplier_name',
    "CALCULATED Total Monthly Potable Water Production Reporting Month Gallons": "total_potable_gal",
    "CALCULATED Total Monthly Potable Water Production 2013 Gallons": "total_potable_gal_2013",
    "CALCULATED Monthly CII Reporting Month": "cii_gal",
    'Reporting Month': 'reporting_month',
    'Total Population Served': 'total_population_served',
    '% Residential Use': 'percent_residential_use',
    'Hydrologic Region': 'hydrologic_region',
    'Conservation Standard (starting in June 2015) *Adjusted in March 2016 **Revised in June 2016': 'conservation_standard'
}
cols = list(df.columns)
for c in cols:
    if c not in col_rename_dict:
        del df[c]
df = df.rename(columns=col_rename_dict)

# %%
# Convert numerical columns from there comma-delimeted and other funky formats
numerical_columns = [c for c in df.columns if '_gal' in c] + ['percent_residential_use', 'total_population_served']
for c in numerical_columns:
    df[c] = df[c].apply(numberize)

# %%
# Compute a bunch of useful columns. Water usage breakdowns, etc.

df['reporting_month'] = pd.to_datetime(df['reporting_month'])
df['month'] = df['reporting_month'].apply(lambda x: x.month)
df['year'] = df['reporting_month'].apply(lambda x: x.year)
df['water_year'] = df['year'] + (df['month'] > 9).astype(int)

# Weirdly, the "total potable water REPORTED" number includes agricultural
# water, whereas the "total potable gallons CALCULATED" does not. The former
# is also reported in a range of units, while the latter converts to gallons.

df['residential_gal'] = df['total_potable_gal'] * (df['percent_residential_use'] / 100.0)
df['other_gal'] = df['total_potable_gal'] * (1 - df['percent_residential_use'] / 100.0) - df['cii_gal']

df['conservation_standard'] = df['conservation_standard'].apply(
    lambda s: 0.0 if pd.isnull(s) else float(s.strip('%')) / 100.0)

df.head()
# Out:
#                            supplier_name reporting_month  \
# 0  East Bay Municipal Utilities District      2016-10-15
# 1  East Bay Municipal Utilities District      2016-09-15
# 2  East Bay Municipal Utilities District      2016-08-15
# 3  East Bay Municipal Utilities District      2016-07-15
# 4  East Bay Municipal Utilities District      2016-06-15
#
#    total_population_served  conservation_standard  total_potable_gal  \
# 0                  1400000                      0         4689900000
# 1                  1400000                      0         5636200000
# 2                  1400000                      0         6007500000
# 3                  1400000                      0         6056600000
# 4                  1400000                      0         5675900000
#
#    total_potable_gal_2013     cii_gal  percent_residential_use  \
# 0              6175000000   956000000                       60
# 1              6528400000   912000000                       61
# 2              7172300000  1141000000                       61
# 3              7452200000   994000000                       60
# 4              6927500000   839000000                       61
#
#    hydrologic_region  month  year  water_year  residential_gal   other_gal
# 0  San Francisco Bay     10  2016        2017       2813940000   919960000
# 1  San Francisco Bay      9  2016        2016       3438082000  1286118000
# 2  San Francisco Bay      8  2016        2016       3664575000  1201925000
# 3  San Francisco Bay      7  2016        2016       3633960000  1428640000
# 4  San Francisco Bay      6  2016        2016       3462299000  1374601000

# %%
def computeUsage(df):
    '''Given a dataframe for a single provider, create usage dict.'''
    usage = defaultdict(dict)
    for i, row in df.iterrows():
        m = row['reporting_month'].strftime('%Y-%m')
        pop = float(row['total_population_served'])
        usage['totalPerCapita'][m] = numberize(row['total_potable_gal']) / pop
        usage['residentialPerCapita'][m] = numberize(row['residential_gal']) / pop
        usage['commercialIndustrialPerCapita'][m] = numberize(row['cii_gal']) / pop
        usage['otherPotablePerCapita'][m] = numberize(row['other_gal']) / pop

    return dict(usage)  # Convert from defaultdict to regular dict

def computePredictions(usage):
    '''Compute monthly usage predictions for the upcoming 12 months.'''
    predictions = {}
    for month in range(1, 13):
        matching_keys = [k for k in usage if k.endswith("%02d" % month)]
        if len(matching_keys) == 0:
            # We have never seen data for this month, can't predict anything
            result = None
        elif len(matching_keys) == 1:
            # Only one occurance of this month, just predict homeostasis
            result = usage[matching_keys[0]]
        else:
            # Assume the year-over-year growth for this month is static.
            matching_keys.sort()
            growth = usage[matching_keys[-1]] / usage[matching_keys[-2]]
            result = usage[matching_keys[-1]] * growth
        predictions['%02d' %  month] = result
    return predictions

def computeTargetUsage(df, year):
    '''Given a dataframe for a single provider, calculate it's usage target for the year.'''
    if len(df[df['water_year'] == year]) < 12:
        print("Don't have complete data for water year %d, skipping..." % (year))
        return None
    reduction = df.loc[datetime.datetime(year - 1, 10, 15), 'conservation_standard']
    df_year = df[df['water_year'] == year]
    used_year = (df_year['total_potable_gal_2013'] / df_year['total_population_served']).sum()
    return (1 - reduction) * used_year

# %%
# One dataset identifies water suppliers by ID, the other merely by name. We need to pair them.

providers = pd.read_csv(DATA_DIR + 'provider_ids.tsv', sep='\t')
provider_id_lookup = {}
for p, i in zip(providers['Provider'], providers['ID']):
    provider_id_lookup[p.lower()] = i

# %%
js = {}
for i, items in enumerate(df.groupby("supplier_name").groups.items()):
    name, indices = items
    print(i, name)
    name = name.lower()
    if name not in provider_id_lookup:
        print("Can't find supplier ID for '%s', skipping..." % name)
        continue

    supplier_df = df.loc[indices].set_index('reporting_month', drop=False)
    usage = computeUsage(supplier_df)
    total = usage['totalPerCapita']
    del usage['totalPerCapita']
    preds = computePredictions(total)
    target_2016 = computeTargetUsage(supplier_df, 2016)
    target_2015 = computeTargetUsage(supplier_df, 2015)
    if target_2016 is None or target_2015 is None:
        continue

    js[provider_id_lookup[name]] = {
        "agencyName": name,
        "totalUsage": total,
        "usageByCategory": usage,
        "monthlyPrediction": preds,
        "annualTarget": target_2016,
        "previousTarget": target_2015,
    }
# Out:
# 0 Santa Barbara  City of
# 1 San Gabriel Valley Fontana Water Company
# 2 Del Oro Water Company
# 3 Lincoln Avenue Water Company
# 4 San Jacinto  City of
# 5 San Buenaventura  City of
# 6 California Water Service Company Willows
# 7 Pismo Beach  City of
# 8 Estero Municipal Improvement District
# 9 Poway  City of
# 10 Corona  City of
# 11 La Palma  City of
# 12 Los Angeles County Public Works Waterworks District 29
# 13 Trabuco Canyon Water District
# 14 Tulare, City of
# 15 Bellflower-Somerset Mutual Water Company
# 16 Imperial, City of
# 17 Lemoore  City of
# 18 California Water Service Company Westlake
# 19 Phelan Pinon Hills Community Services District
# 20 Dublin San Ramon Services District
# 21 Beaumont-Cherry Valley Water District
# 22 Buena Park  City of
# 23 Las Virgenes Municipal Water District
# 24 Yuba City  City of
# 25 Valley County Water District
# 26 Golden State Water Company S Arcadia
# 27 Burbank  City of
# 28 Fresno  City of
# 29 California Water Service Company Selma
# 30 Rosamond Community Service District
# 31 Padre Dam Municipal Water District
# 32 McKinleyville Community Service District
# 33 Oceanside  City of
# 34 San Gabriel Valley Water Company
# 35 Arvin Community Services District
# 36 Arroyo Grande  City of
# 37 California Water Service Company Livermore
# 38 Mission Springs Water District
# Don't have complete data for water year 2016, skipping...
# 39 Ventura County Waterworks District No 1
# 40 Chino  City of
# 41 Redlands  City of
# 42 Vaughn Water Company
# 43 California Water Service Company Kern River Valley
# 44 Linda County Water District
# 45 Escondido  City of
# 46 Lompoc  City of
# 47 Hayward  City of
# 48 San Fernando  City of
# 49 Indio  City of
# 50 Lake Arrowhead Community Services District
# 51 Lomita  City of
# 52 Santa Monica  City of
# 53 Sacramento  City of
# 54 Dinuba  City of
# 55 Golden State Water Company Artesia
# 56 Grover Beach  City of
# 57 North Coast County Water District
# 58 Newport Beach  City of
# 59 Coachella  City of
# 60 Arcadia  City of
# 61 California Water Service Company Dixon, City of
# 62 San Gabriel County Water District
# 63 Golden State Water Company Florence Graham
# 64 Nipomo Community Services District
# 65 Riverside Highland Water Company
# 66 California Water Service Company Visalia
# 67 San Francisco Public Utilities Commission
# 68 Fruitridge Vista Water Company
# 69 Napa  City of
# 70 Colton, City of
# 71 Sacramento County Water Agency
# 72 Castaic Lake Water Agency Santa Clarita Water Division
# 73 Golden State Water Company Cordova
# 74 Corcoran, City of
# Can't find supplier ID for 'corcoran, city of', skipping...
# 75 Watsonville  City of
# 76 California Water Service Company Hermosa/Redondo
# 77 Tehachapi, City of
# 78 Riverside  City of
# 79 El Toro Water District
# 80 Palo Alto  City of
# 81 Soquel Creek Water District
# 82 Benicia  City of
# 83 Antioch  City of
# 84 Monterey Park  City of
# 85 Westborough Water District
# 86 Whittier  City of
# 87 Soledad, City of
# 88 Fairfield  City of
# 89 Mountain House Community Services District
# Can't find supplier ID for 'mountain house community services district', skipping...
# 90 Citrus Heights Water District
# 91 Ventura County Waterworks District No. 8
# 92 Vista Irrigation District
# 93 Rancho California Water District
# 94 Tustin  City of
# 95 California Water Service Company Chico District
# 96 Pleasanton  City of
# 97 Lake Hemet Municipal Water District
# 98 Banning  City of
# 99 Scotts Valley Water District
# 100 San Bernardino County Service Area 70J
# Can't find supplier ID for 'san bernardino county service area 70j', skipping...
# 101 Rialto  City of
# 102 Goleta Water District
# 103 Orchard Dale Water District
# 104 Placer County Water Agency
# 105 Vernon  City of
# 106 California-American Water Company Monterey District
# 107 California Water Service Company Redwood Valley
# 108 Paradise Irrigation District
# 109 Los Banos, City of
# 110 Paramount  City of
# 111 North Marin Water District
# 112 California Water Service Company Dominguez
# 113 Glendale  City of
# 114 Santa Rosa  City of
# 115 Davis  City of
# 116 Rohnert Park  City of
# 117 Golden State Water Company Bell-Bell Gardens
# 118 Santa Fe Irrigation District
# 119 Pinedale County Water District
# 120 Twentynine Palms Water District
# 121 Manhattan Beach  City of
# 122 Bakman Water Company
# 123 California Water Service Company Marysville
# 124 San Dieguito Water District
# 125 Eastern Municipal Water District
# 126 Cerritos  City of
# 127 Joshua Basin Water District
# 128 Quartz Hill Water District
# 129 California Water Service Company East Los Angeles
# 130 Tahoe City Public Utilities District
# 131 Rubio Canyon Land and Water Association
# 132 Pasadena  City of
# 133 El Dorado Irrigation District
# 134 Redding  City of
# 135 Golden State Water Company Barstow
# 136 Riverbank  City of
# 137 Fountain Valley  City of
# 138 Lakeside Water District
# 139 Chino Hills  City of
# 140 Apple Valley Ranchos Water Company
# 141 Montecito Water District
# 142 Desert Water Agency
# 143 Western Municipal Water District of Riverside
# 144 Tracy  City of
# 145 El Segundo  City of
# 146 East Valley Water District
# 147 East Orange County Water District
# Don't have complete data for water year 2016, skipping...
# 148 Oakdale  City of
# 149 Crescenta Valley Water District
# 150 Sanger  City of
# 151 Moulton Niguel Water District
# 152 Hesperia Water District City of
# 153 Gilroy  City of
# 154 Sonoma  City of
# 155 Truckee-Donner Public Utilities District
# 156 El Monte  City of
# 157 Golden State Water Company Placentia
# 158 Livingston  City of
# 159 Discovery Bay Community Services District
# 160 Folsom  City of
# 161 Golden State Water Company S San Gabriel
# 162 Atascadero Mutual Water Company
# 163 Golden State Water Company Orcutt
# 164 California Water Service Company Antelope Valley
# 165 La Verne  City of
# 166 South Tahoe Public Utilities District
# 167 Marina Coast Water District
# 168 Covina  City of
# Can't find supplier ID for 'covina  city of ', skipping...
# 169 California Water Service Company Stockton
# 170 Ontario  City of
# 171 Los Angeles Department of Water and Power
# 172 Long Beach  City of
# 173 Westminster  City of
# 174 Lakewood  City of
# 175 Fair Oaks Water District
# 176 California Water Service Company Bakersfield
# 177 Exeter  City of
# 178 Park Water Company
# 179 Pomona  City of
# 180 San Juan Capistrano  City of
# 181 Crestline Village Water District
# 182 Woodland  City of
# 183 Nevada Irrigation District
# 184 Montebello Land and Water Company
# 185 San Juan Water District
# 186 California Water Service Company Palos Verdes
# 187 Los Angeles County Public Works Waterworks District 40
# 188 Suburban Water Systems San Jose Hills
# 189 Coastside County Water District
# 190 Norwalk City of
# 191 Calexico  City of
# Don't have complete data for water year 2016, skipping...
# 192 Elsinore Valley Municipal Water District
# 193 Adelanto City of
# 194 Mountain View  City of
# 195 Downey  City of
# 196 Ukiah  City of
# 197 Helix Water District
# 198 Santa Paula  City of
# 199 Oildale Mutual Water Company
# 200 Sunnyslope County Water District
# 201 South Coast Water District
# 202 Stockton  City of
# 203 Inglewood  City of
# 204 Merced  City of
# 205 Modesto, City of
# 206 Upland  City of
# 207 Contra Costa Water District
# 208 West Valley Water District
# 209 West Sacramento  City of
# 210 Monrovia  City of
# 211 Petaluma  City of
# 212 Alco Water Service
# 213 Laguna Beach County Water District
# 214 Jurupa Community Service District
# 215 Pico Water District
# 216 Golden State Water Company Bay Point
# 217 Thousand Oaks  City of
# 218 La Habra  City of Public Works
# 219 Menlo Park  City of
# 220 Santa Fe Springs  City of
# 221 Sacramento Suburban Water District
# 222 Humboldt Bay Municipal Water District
# 223 Hawthorne  City of
# 224 Otay Water District
# 225 Daly City  City of
# 226 Georgetown Divide Public Utilities District
# 227 Lee Lake Water District
# 228 San Bernardino  City of
# 229 Fillmore  City of
# 230 Morgan Hill  City of
# Don't have complete data for water year 2015, skipping...
# 231 Vallecitos Water District
# 232 Port Hueneme  City of
# 233 Red Bluff  City of
# 234 Pico Rivera  City of
# 235 Anaheim  City of
# 236 California Water Service Company Bear Gulch
# 237 Santa Cruz  City of
# 238 Hollister  City of
# 239 East Niles Community Service District
# 240 Carlsbad Municipal Water District
# 241 Redwood City  City of
# 242 Olivehurst Public Utility District
# Can't find supplier ID for 'olivehurst public utility district', skipping...
# 243 Rincon Del Diablo Municipal Water District
# 244 Tuolumne Utilities District
# 245 California Water Service Company South San Francisco
# 246 Golden State Water Company Southwest
# 247 Santa Maria  City of
# 248 Lodi  City of Public Works Department
# 249 Brea  City of
# 250 Reedley  City of
# 251 Palmdale Water District
# 252 Walnut Valley Water District
# 253 Glendora  City of
# 254 Rainbow Municipal Water District
# 255 Coachella Valley Water District
# 256 California Water Service Company Oroville
# 257 San Jose Water Company
# 258 Victorville Water District
# 259 Hillsborough  Town of
# 260 Great Oaks Water Company Incorporated
# 261 Kingsburg, City of
# 262 Perris, City of
# 263 Fullerton  City of
# 264 Vallejo  City of
# 265 San Lorenzo Valley Water District
# Don't have complete data for water year 2015, skipping...
# 266 Azusa  City of
# 267 Suisun-Solano Water Authority
# 268 Lynwood  City of
# 269 Fortuna  City of
# 270 San Jose  City of
# 271 Wasco  City of
# 272 Carmichael Water District
# 273 Carpinteria Valley Water District
# 274 Indian Wells Valley Water District
# 275 Martinez  City of
# 276 Groveland Community Services District
# 277 San Bruno  City of
# 278 Burlingame  City of
# 279 Golden State Water Company San Dimas
# 280 Monte Vista Water District
# 281 El Centro  City of
# 282 Santa Ana  City of
# 283 Golden State Water Company Claremont
# 284 Orange Vale Water Company
# 285 Humboldt Community Service District
# 286 Bakersfield  City of
# 287 Fallbrook Public Utility District
# 288 Mammoth Community Water District
# 289 Roseville  City of
# 290 Olivenhain Municipal Water District
# 291 California-American Water Company San Diego District
# 292 Golden State Water Company Simi Valley
# 293 Eureka  City of
# 294 California Water Service Company Salinas District
# 295 Norco  City of
# 296 Santa Clara  City of
# 297 Mid-Peninsula Water District
# 298 Hemet  City of
# 299 Sunny Slope Water Company
# 300 Paso Robles  City of
# 301 California Water Service Company King City
# 302 Calaveras County Water District
# 303 Marin Municipal Water District
# 304 Hanford  City of
# 305 Irvine Ranch Water District
# 306 Bella Vista Water District
# 307 Huntington Beach  City of
# 308 Turlock  City of
# 309 Torrance  City of
# Don't have complete data for water year 2016, skipping...
# 310 Triunfo Sanitation District / Oak Park Water Service
# 311 Shasta Lake  City of
# 312 Cucamonga Valley Water District
# 313 California Water Service Company Los Altos/Suburban
# 314 Diablo Water District
# 315 Golden State Water Company Norwalk
# 316 City of Newman Water Department
# Can't find supplier ID for 'city of newman water department', skipping...
# 317 Camrosa Water District
# 318 Morro Bay  City of
# 319 Delano  City of
# 320 Lamont Public Utility District
# 321 California Water Service Company Mid Peninsula
# 322 Sierra Madre  City of
# Don't have complete data for water year 2015, skipping...
# 323 Crescent City  City of
# 324 Big Bear City Community Services District
# Can't find supplier ID for 'big bear city community services district', skipping...
# 325 Sweetwater Authority
# 326 Mesa Water District
# Can't find supplier ID for 'mesa water district', skipping...
# 327 Susanville  City of
# Don't have complete data for water year 2016, skipping...
# 328 Anderson, City of
# Don't have complete data for water year 2016, skipping...
# Don't have complete data for water year 2015, skipping...
# 329 Beverly Hills  City of
# 330 Vacaville  City of
# Don't have complete data for water year 2015, skipping...
# 331 Casitas Municipal Water District
# 332 Santa Margarita Water District
# 333 Valencia Water Company
# 334 City of Big Bear Lake, Dept of Water & Power
# Can't find supplier ID for 'city of big bear lake, dept of water & power', skipping...
# 335 Rubidoux Community Service District
# 336 Loma Linda  City of *
# Can't find supplier ID for 'loma linda  city of *', skipping...
# 337 California-American Water Company Sacramento District
# 338 Sunnyvale  City of
# 339 Blythe  City of
# 340 Cloverdale
# Don't have complete data for water year 2016, skipping...
# Don't have complete data for water year 2015, skipping...
# 341 Galt  City of
# 342 North Tahoe Public Utility District
# 343 California-American Water Company Los Angeles District
# 344 Oxnard  City of
# 345 Valley Center Municipal Water District
# 346 Golden State Water Company Culver City
# 347 Rowland Water District
# 348 California-American Water Ventura District
# 349 Patterson  City of
# 350 South Feather Water and Power Agency
# Don't have complete data for water year 2016, skipping...
# 351 Yreka, City of
# 352 Newhall County Water District
# 353 Alameda County Water District
# 354 American Canyon, City of
# 355 Yorba Linda Water District
# 356 Huntington Park  City of
# 357 Brentwood  City of
# 358 East Palo Alto, City of
# 359 Greenfield, City of
# 360 California City  City of
# 361 Orange  City of
# 362 Myoma Dunes Mutual Water Company
# 363 Millbrae  City of
# 364 Windsor, Town of
# 365 Manteca  City of
# 366 Alhambra  City of
# 367 Golden State Water Company West Orange
# 368 Clovis  City of
# 369 Amador Water Agency
# 370 Ceres  City of
# 371 San Bernardino County Service Area 64
# 372 West Kern Water District
# 373 Valley of the Moon Water District
# 374 Valley Water Company
# 375 Shafter  City of
# 376 Atwater  City of
# 377 Compton  City of
# 378 Madera  City of
# 379 San Luis Obispo  City of
# 380 Rio Vista, city of
# 381 Milpitas  City of
# 382 Pittsburg  City of
# 383 East Bay Municipal Utilities District
# 384 Camarillo  City of
# 385 Arcata  City of
# 386 Livermore  City of Division of Water Resources
# 387 Coalinga City of
# Can't find supplier ID for 'coalinga city of', skipping...
# 388 Hi-Desert Water District
# 389 Brawley  City of
# 390 Healdsburg  City of
# 391 Sweetwater Springs Water District
# 392 Yucaipa Valley Water District
# 393 Lincoln  City of
# 394 Rio Linda - Elverta Community Water District
# 395 Ripon  City of
# 396 Porterville  City of
# 397 San Diego  City of
# 398 Lathrop, City of
# Can't find supplier ID for 'lathrop, city of ', skipping...
# 399 Ramona Municipal Water District
# 400 Seal Beach  City of
# 401 Kerman, City of
# Don't have complete data for water year 2015, skipping...
# 402 San Clemente  City of
# 403 Cambria Community Services District
# 404 Elk Grove Water Service
# 405 South Gate  City of
# 406 Suburban Water Systems Whittier/La Mirada
# 407 South Pasadena  City of
# Don't have complete data for water year 2015, skipping...
# 408 Garden Grove  City of

# %%
js[provider_id_lookup['East Bay Municipal Utilities District'.lower()]]
# Out:
# {'agencyName': 'east bay municipal utilities district',
#  'annualTarget': 41681.397410071942,
#  'monthlyPrediction': {'01': 2417.0425868076827,
#   '02': 2307.3946062486384,
#   '03': 2162.496771084676,
#   '04': 2569.9142125418007,
#   '05': 3744.794391501367,
#   '06': 4781.496866924954,
#   '07': 5052.842907325889,
#   '08': 4874.674539013777,
#   '09': 4451.649133761039,
#   '10': 3195.7815596816476,
#   '11': 2555.6796736092665,
#   '12': 2564.2099279337895},
#  'previousTarget': 49986.756329526652,
#  'totalUsage': {'2014-06': 4786.015037593985,
#   '2014-07': 4954.962406015037,
#   '2014-08': 4511.965192168238,
#   '2014-09': 4121.02973168963,
#   '2014-10': 3894.5612762871647,
#   '2014-11': 3042.3495286439447,
#   '2014-12': 2783.901377810007,
#   '2015-01': 2946.906474820144,
#   '2015-02': 2709.2805755395684,
#   '2015-03': 3345.4676258992804,
#   '2015-04': 3206.4028776978416,
#   '2015-05': 3350.863309352518,
#   '2015-06': 3437.5539568345325,
#   '2015-07': 3703.956834532374,
#   '2015-08': 3777.338129496403,
#   '2015-09': 3640.7913669064747,
#   '2015-10': 3511.5107913669067,
#   '2015-11': 2788.4172661870502,
#   '2015-12': 2671.798561151079,
#   '2016-01': 2668.8571428571427,
#   '2016-02': 2500.275862142857,
#   '2016-03': 2689.714285714286,
#   '2016-04': 2870.5714285714284,
#   '2016-05': 3542.3571428571427,
#   '2016-06': 4054.214285714286,
#   '2016-07': 4326.142857142857,
#   '2016-08': 4291.071428571428,
#   '2016-09': 4025.8571428571427,
#   '2016-10': 3349.9285714285716},
#  'usageByCategory': {'commercialIndustrialPerCapita': {'2014-06': 0.0,
#    '2014-07': 0.0,
#    '2014-08': 0.0,
#    '2014-09': 0.0,
#    '2014-10': 0.0,
#    '2014-11': 0.0,
#    '2014-12': 0.0,
#    '2015-01': 0.0,
#    '2015-02': 0.0,
#    '2015-03': 0.0,
#    '2015-04': 0.0,
#    '2015-05': 0.0,
#    '2015-06': 653.8129496402878,
#    '2015-07': 687.0503597122303,
#    '2015-08': 717.410071942446,
#    '2015-09': 720.5035971223022,
#    '2015-10': 715.8273381294964,
#    '2015-11': 609.3525179856115,
#    '2015-12': 606.4748201438849,
#    '2016-01': 857.8571428571429,
#    '2016-02': 564.1379307142857,
#    '2016-03': 578.5714285714286,
#    '2016-04': 592.8571428571429,
#    '2016-05': 682.1428571428571,
#    '2016-06': 599.2857142857143,
#    '2016-07': 710.0,
#    '2016-08': 815.0,
#    '2016-09': 651.4285714285714,
#    '2016-10': 682.8571428571429},
#   'otherPotablePerCapita': {'2014-06': 1483.6646616541354,
#    '2014-07': 1536.0383458646618,
#    '2014-08': 1759.6664249456128,
#    '2014-09': 1607.2015953589557,
#    '2014-10': 1557.8245105148658,
#    '2014-11': 1186.5163161711384,
#    '2014-12': 1057.8825235678028,
#    '2015-01': 1119.8244604316546,
#    '2015-02': 1056.6194244604317,
#    '2015-03': 1304.7323741007194,
#    '2015-04': 1218.4330935251799,
#    '2015-05': 1340.3453237410072,
#    '2015-06': 686.8330935251798,
#    '2015-07': 794.5323741007194,
#    '2015-08': 755.7517985611511,
#    '2015-09': 699.405035971223,
#    '2015-10': 688.7769784172662,
#    '2015-11': 478.13021582733813,
#    '2015-12': 408.8086330935252,
#    '2016-01': 156.30857142857144,
#    '2016-02': 410.9696555214286,
#    '2016-03': 470.41714285714284,
#    '2016-04': 497.96,
#    '2016-05': 734.8,
#    '2016-06': 981.8578571428571,
#    '2016-07': 1020.4571428571429,
#    '2016-08': 858.5178571428571,
#    '2016-09': 918.6557142857143,
#    '2016-10': 657.1142857142858},
#   'residentialPerCapita': {'2014-06': 3302.3503759398495,
#    '2014-07': 3418.924060150376,
#    '2014-08': 2752.298767222625,
#    '2014-09': 2513.8281363306746,
#    '2014-10': 2336.736765772299,
#    '2014-11': 1855.8332124728063,
#    '2014-12': 1726.0188542422045,
#    '2015-01': 1827.0820143884891,
#    '2015-02': 1652.6611510791367,
#    '2015-03': 2040.7352517985612,
#    '2015-04': 1987.9697841726618,
#    '2015-05': 2010.5179856115108,
#    '2015-06': 2096.907913669065,
#    '2015-07': 2222.3741007194244,
#    '2015-08': 2304.1762589928057,
#    '2015-09': 2220.8827338129495,
#    '2015-10': 2106.906474820144,
#    '2015-11': 1700.9345323741006,
#    '2015-12': 1656.515107913669,
#    '2016-01': 1654.6914285714286,
#    '2016-02': 1525.1682759071427,
#    '2016-03': 1640.7257142857143,
#    '2016-04': 1779.7542857142857,
#    '2016-05': 2125.4142857142856,
#    '2016-06': 2473.070714285714,
#    '2016-07': 2595.6857142857143,
#    '2016-08': 2617.5535714285716,
#    '2016-09': 2455.772857142857,
#    '2016-10': 2009.9571428571428}}}

# %%
with open(DATA_DIR + 'usage.json', 'w') as f:
    f.write(json.dumps(js, indent=4))
